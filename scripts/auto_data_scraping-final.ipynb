# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)

# %%
import requests
from bs4 import BeautifulSoup
import time
import re
import pandas as pd
import os

# %%
def fetch_brand_urls():
    base_url = "https://www.auto-data.net/en/"
    response = requests.get(base_url)
    soup = BeautifulSoup(response.content, "html.parser")

    # Correct selector: all <a class="marki_blok">
    brand_links = soup.find_all("a", class_="marki_blok")
    brands = []

    for a_tag in brand_links:
        if a_tag and "title" in a_tag.attrs and "href" in a_tag.attrs:
            # Get clean brand name
            brand_name = a_tag["title"].split(" - ")[0].strip()

            # Remove leading "/en/" and build full URL
            raw_href = a_tag["href"]
            cleaned_path = raw_href.replace("/en/", "", 1)
            full_url = base_url + cleaned_path

            brands.append((brand_name, full_url))

    return brands

def print_brands_and_urls2(brands):
    for name, url in brands:
        print(f"{name}: {url}")

if __name__ == "__main__":
    brand_links = fetch_brand_urls()
    print_brands_and_urls2(brand_links)
# Out:
# Acura: https://www.auto-data.net/en/acura-brand-6
# Alfa Romeo: https://www.auto-data.net/en/alfa-romeo-brand-11
# Alpina: https://www.auto-data.net/en/alpina-brand-16
# Aston Martin: https://www.auto-data.net/en/aston-martin-brand-36
# Audi: https://www.auto-data.net/en/audi-brand-41
# Bentley: https://www.auto-data.net/en/bentley-brand-66
# BMW: https://www.auto-data.net/en/bmw-brand-86
# Bugatti: https://www.auto-data.net/en/bugatti-brand-106
# BYD: https://www.auto-data.net/en/byd-brand-116
# Cadillac: https://www.auto-data.net/en/cadillac-brand-121
# Chevrolet: https://www.auto-data.net/en/chevrolet-brand-156
# Chrysler: https://www.auto-data.net/en/chrysler-brand-161
# Citroen: https://www.auto-data.net/en/citroen-brand-166
# Cupra: https://www.auto-data.net/en/cupra-brand-256
# Dacia: https://www.auto-data.net/en/dacia-brand-181
# Daewoo: https://www.auto-data.net/en/daewoo-brand-191
# Daihatsu: https://www.auto-data.net/en/daihatsu-brand-2
# Dodge: https://www.auto-data.net/en/dodge-brand-32
# DS: https://www.auto-data.net/en/ds-brand-198
# Ferrari: https://www.auto-data.net/en/ferrari-brand-62
# Fiat: https://www.auto-data.net/en/fiat-brand-67
# Ford: https://www.auto-data.net/en/ford-brand-72
# Genesis: https://www.auto-data.net/en/genesis-brand-202
# GMC: https://www.auto-data.net/en/gmc-brand-97
# Great Wall: https://www.auto-data.net/en/great-wall-brand-107
# Haval: https://www.auto-data.net/en/haval-brand-214
# Honda: https://www.auto-data.net/en/honda-brand-127
# Hongqi: https://www.auto-data.net/en/hongqi-brand-296
# Hummer: https://www.auto-data.net/en/hummer-brand-137
# Hyundai: https://www.auto-data.net/en/hyundai-brand-147
# Infiniti: https://www.auto-data.net/en/infiniti-brand-152
# Jaguar: https://www.auto-data.net/en/jaguar-brand-3
# Jeep: https://www.auto-data.net/en/jeep-brand-8
# Kia: https://www.auto-data.net/en/kia-brand-23
# Koenigsegg: https://www.auto-data.net/en/koenigsegg-brand-28
# Lada: https://www.auto-data.net/en/lada-brand-140
# Lamborghini: https://www.auto-data.net/en/lamborghini-brand-38
# Lancia: https://www.auto-data.net/en/lancia-brand-43
# Land Rover: https://www.auto-data.net/en/land-rover-brand-48
# Lexus: https://www.auto-data.net/en/lexus-brand-58
# Lotus: https://www.auto-data.net/en/lotus-brand-78
# Maserati: https://www.auto-data.net/en/maserati-brand-108
# Mazda: https://www.auto-data.net/en/mazda-brand-118
# McLaren: https://www.auto-data.net/en/mclaren-brand-123
# Mercedes-Benz: https://www.auto-data.net/en/mercedes-benz-brand-138
# MG: https://www.auto-data.net/en/mg-brand-153
# Mini: https://www.auto-data.net/en/mini-brand-168
# Mitsubishi: https://www.auto-data.net/en/mitsubishi-brand-173
# NIO: https://www.auto-data.net/en/nio-brand-295
# Nissan: https://www.auto-data.net/en/nissan-brand-4
# Opel: https://www.auto-data.net/en/opel-brand-19
# Pagani: https://www.auto-data.net/en/pagani-brand-29
# Peugeot: https://www.auto-data.net/en/peugeot-brand-49
# Porsche: https://www.auto-data.net/en/porsche-brand-64
# RAM: https://www.auto-data.net/en/ram-brand-240
# Renault: https://www.auto-data.net/en/renault-brand-99
# Rolls-Royce: https://www.auto-data.net/en/rolls-royce-brand-109
# Rover: https://www.auto-data.net/en/rover-brand-119
# Saab: https://www.auto-data.net/en/saab-brand-124
# Seat: https://www.auto-data.net/en/seat-brand-144
# Skoda: https://www.auto-data.net/en/skoda-brand-154
# Smart: https://www.auto-data.net/en/smart-brand-164
# Subaru: https://www.auto-data.net/en/subaru-brand-189
# Suzuki: https://www.auto-data.net/en/suzuki-brand-194
# Tesla: https://www.auto-data.net/en/tesla-brand-197
# Toyota: https://www.auto-data.net/en/toyota-brand-40
# Vauxhall: https://www.auto-data.net/en/vauxhall-brand-60
# Volkswagen: https://www.auto-data.net/en/volkswagen-brand-80
# Volvo: https://www.auto-data.net/en/volvo-brand-85

# %%
import os

# Model URL for Car-Data website

# Extract brand URLs
brand_links = fetch_brand_urls()

def generate_brand_urls2(brands):
    return [url for _, url in brands]

urls = generate_brand_urls2(brand_links)

# Get all model links for each brand
def get_model_links(brand_url):
    try:
        time.sleep(2)  # Be polite to the server

        response = requests.get(brand_url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        models = []

        # Find all a tags with class 'modeli'
        model_tags = soup.find_all('a', class_='modeli')

        for tag in model_tags:
            href = tag['href']
            full_url = "https://www.auto-data.net" + href

            title = tag.get('title', '').strip()
            if not title:
                continue

            title_parts = title.split()
            if len(title_parts) < 2:
                continue

            brand = title_parts[0]
            model = title_parts[1]

            models.append({
                'brand': brand.lower(),
                'model': model.lower().replace(' ', '-'),
                'title': title.lower(),
                'url': full_url
            })

        return models

    except Exception as e:
        print(f"Error processing {brand_url}: {str(e)}")
        return []

# Generate and collect all model data
def generate_model_urls():
    all_models = []
    for brand_url in urls:
        print(f"Processing {brand_url}...")
        model_links = get_model_links(brand_url)
        all_models.extend(model_links)
        print(f"Found {len(model_links)} models.")
    return all_models

# Export to CSV
model_links = generate_model_urls()
model_df = pd.DataFrame(model_links)

# Ensure the 'data' directory exists
os.makedirs('data', exist_ok=True)

# Save the file
model_df.to_csv('data/auto-data-model-links-table.csv', index=True)

print("Model data saved to 'data/auto-data-model-links-table.csv'")
# Out:
# Processing https://www.auto-data.net/en/acura-brand-6...
# Found 17 models.
# Processing https://www.auto-data.net/en/alfa-romeo-brand-11...
# Found 33 models.
# Processing https://www.auto-data.net/en/alpina-brand-16...
# Found 22 models.
# Processing https://www.auto-data.net/en/aston-martin-brand-36...
# Found 25 models.
# Processing https://www.auto-data.net/en/audi-brand-41...
# Found 62 models.
# Processing https://www.auto-data.net/en/bentley-brand-66...
# Found 11 models.
# Processing https://www.auto-data.net/en/bmw-brand-86...
# Found 50 models.
# Processing https://www.auto-data.net/en/bugatti-brand-106...
# Found 11 models.
# Processing https://www.auto-data.net/en/byd-brand-116...
# Found 37 models.
# Processing https://www.auto-data.net/en/cadillac-brand-121...
# Found 30 models.
# Processing https://www.auto-data.net/en/chevrolet-brand-156...
# Found 80 models.
# Processing https://www.auto-data.net/en/chrysler-brand-161...
# Found 28 models.
# Processing https://www.auto-data.net/en/citroen-brand-166...
# Found 46 models.
# Processing https://www.auto-data.net/en/cupra-brand-256...
# Found 10 models.
# Processing https://www.auto-data.net/en/dacia-brand-181...
# Found 16 models.
# Processing https://www.auto-data.net/en/daewoo-brand-191...
# Found 25 models.
# Processing https://www.auto-data.net/en/daihatsu-brand-2...
# Found 33 models.
# Processing https://www.auto-data.net/en/dodge-brand-32...
# Found 23 models.
# Processing https://www.auto-data.net/en/ds-brand-198...
# Found 7 models.
# Processing https://www.auto-data.net/en/ferrari-brand-62...
# Found 50 models.
# Processing https://www.auto-data.net/en/fiat-brand-67...
# Found 59 models.
# Processing https://www.auto-data.net/en/ford-brand-72...
# Found 73 models.
# Processing https://www.auto-data.net/en/genesis-brand-202...
# Found 6 models.
# Processing https://www.auto-data.net/en/gmc-brand-97...
# Found 17 models.
# Processing https://www.auto-data.net/en/great-wall-brand-107...
# Found 18 models.
# Processing https://www.auto-data.net/en/haval-brand-214...
# Found 15 models.
# Processing https://www.auto-data.net/en/honda-brand-127...
# Found 79 models.
# Processing https://www.auto-data.net/en/hongqi-brand-296...
# Found 11 models.
# Processing https://www.auto-data.net/en/hummer-brand-137...
# Found 3 models.
# Processing https://www.auto-data.net/en/hyundai-brand-147...
# Found 65 models.
# Processing https://www.auto-data.net/en/infiniti-brand-152...
# Found 22 models.
# Processing https://www.auto-data.net/en/jaguar-brand-3...
# Found 15 models.
# Processing https://www.auto-data.net/en/jeep-brand-8...
# Found 15 models.
# Processing https://www.auto-data.net/en/kia-brand-23...
# Found 59 models.
# Processing https://www.auto-data.net/en/koenigsegg-brand-28...
# Found 7 models.
# Processing https://www.auto-data.net/en/lada-brand-140...
# Found 31 models.
# Processing https://www.auto-data.net/en/lamborghini-brand-38...
# Found 29 models.
# Processing https://www.auto-data.net/en/lancia-brand-43...
# Found 20 models.
# Processing https://www.auto-data.net/en/land-rover-brand-48...
# Found 10 models.
# Processing https://www.auto-data.net/en/lexus-brand-58...
# Found 21 models.
# Processing https://www.auto-data.net/en/lotus-brand-78...
# Found 16 models.
# Processing https://www.auto-data.net/en/maserati-brand-108...
# Found 30 models.
# Processing https://www.auto-data.net/en/mazda-brand-118...
# Found 74 models.
# Processing https://www.auto-data.net/en/mclaren-brand-123...
# Found 21 models.
# Processing https://www.auto-data.net/en/mercedes-benz-brand-138...
# Found 73 models.
# Processing https://www.auto-data.net/en/mg-brand-153...
# Found 36 models.
# Processing https://www.auto-data.net/en/mini-brand-168...
# Found 9 models.
# Processing https://www.auto-data.net/en/mitsubishi-brand-173...
# Found 61 models.
# Processing https://www.auto-data.net/en/nio-brand-295...
# Found 10 models.
# Processing https://www.auto-data.net/en/nissan-brand-4...
# Found 96 models.
# Processing https://www.auto-data.net/en/opel-brand-19...
# Found 40 models.
# Processing https://www.auto-data.net/en/pagani-brand-29...
# Found 3 models.
# Processing https://www.auto-data.net/en/peugeot-brand-49...
# Found 47 models.
# Processing https://www.auto-data.net/en/porsche-brand-64...
# Found 22 models.
# Processing https://www.auto-data.net/en/ram-brand-240...
# Found 2 models.
# Processing https://www.auto-data.net/en/renault-brand-99...
# Found 71 models.
# Processing https://www.auto-data.net/en/rolls-royce-brand-109...
# Found 11 models.
# Processing https://www.auto-data.net/en/rover-brand-119...
# Found 14 models.
# Processing https://www.auto-data.net/en/saab-brand-124...
# Found 11 models.
# Processing https://www.auto-data.net/en/seat-brand-144...
# Found 20 models.
# Processing https://www.auto-data.net/en/skoda-brand-154...
# Found 25 models.
# Processing https://www.auto-data.net/en/smart-brand-164...
# Found 8 models.
# Processing https://www.auto-data.net/en/subaru-brand-189...
# Found 28 models.
# Processing https://www.auto-data.net/en/suzuki-brand-194...
# Found 43 models.
# Processing https://www.auto-data.net/en/tesla-brand-197...
# Found 7 models.
# Processing https://www.auto-data.net/en/toyota-brand-40...
# Found 149 models.
# Processing https://www.auto-data.net/en/vauxhall-brand-60...
# Found 37 models.
# Processing https://www.auto-data.net/en/volkswagen-brand-80...
# Found 79 models.
# Processing https://www.auto-data.net/en/volvo-brand-85...
# Found 40 models.
# Model data saved to 'data/auto-data-model-links-table.csv'

# %%
#Variant url for auto-data
import requests
import time
import random
from bs4 import BeautifulSoup

# Safe request with headers, timeout, and polite delay
def safe_request(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
    }

    try:
        print(f"Requesting: {url}")

        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        return response
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
        return None

# Variant URL extractor
def extract_variant_links(model_url, model_title):
    try:
        response = safe_request(model_url)
        if not response:
            return []

        soup = BeautifulSoup(response.text, 'html.parser')
        variant_links = []

        table = soup.find('table', class_='generr')
        if not table:
            print(f"No variant table found for {model_url}")
            return []

        for a_tag in table.find_all('a', href=True, title=True):
            href = a_tag['href']
            title_full = a_tag['title']

            # Trim the title to remove everything after ' - Technical'
            title_trimmed = title_full.split(' - Technical')[0].strip()

            # Split the title into parts
            title_parts = title_trimmed.split()
            if len(title_parts) < 2:
                continue

            brand = title_parts[1].lower() if title_parts[0].isdigit() else title_parts[0].lower()

            # The model is everything after the brand
            model_start = 1 if title_parts[0].isdigit() else 1
            model_parts = title_parts[model_start:]
            model = ' '.join(model_parts).lower()

            variant_id = href.split('-')[-1]
            variant_links.append({
                'brand': brand,
                'model': model,
                'variant_url': 'https://www.auto-data.net' + href,
                'variant_title': title_trimmed,
                'variant_id': variant_id
            })

        return variant_links

    except Exception as e:
        print(f"Error processing {model_url}: {str(e)}")
        return []


def process_models_for_variants2(models_list):
    all_variants = []

    # Limit to first 5 models for testing
    limited_models = models_list

    for model in limited_models:
        print(f"Requesting: {model['url']}")
        variants = extract_variant_links(model['url'], model['title'])
        all_variants.extend(variants)

    return all_variants

variant_links = process_models_for_variants2(model_links)


variants_df = pd.DataFrame(variant_links)
variants_df.to_csv('data/auto-data-variants-links-table.csv', index=True)

variant_links
# Out:
# Requesting: https://www.auto-data.net/en/acura-adx-model-3586
# Requesting: https://www.auto-data.net/en/acura-adx-model-3586
# Requesting: https://www.auto-data.net/en/acura-cl-model-138
# Requesting: https://www.auto-data.net/en/acura-cl-model-138
# Requesting: https://www.auto-data.net/en/acura-csx-model-143
# Requesting: https://www.auto-data.net/en/acura-csx-model-143
# Requesting: https://www.auto-data.net/en/acura-el-model-148
# Requesting: https://www.auto-data.net/en/acura-el-model-148
# Requesting: https://www.auto-data.net/en/acura-ilx-model-1994
# Requesting: https://www.auto-data.net/en/acura-ilx-model-1994
# Requesting: https://www.auto-data.net/en/acura-integra-model-2258
# Requesting: https://www.auto-data.net/en/acura-integra-model-2258
# Requesting: https://www.auto-data.net/en/acura-mdx-model-144
# Requesting: https://www.auto-data.net/en/acura-mdx-model-144
# Requesting: https://www.auto-data.net/en/acura-nsx-model-149
# Requesting: https://www.auto-data.net/en/acura-nsx-model-149
# Requesting: https://www.auto-data.net/en/acura-rdx-model-140
# Requesting: https://www.auto-data.net/en/acura-rdx-model-140
# Requesting: https://www.auto-data.net/en/acura-rl-model-145
# Requesting: https://www.auto-data.net/en/acura-rl-model-145
# Requesting: https://www.auto-data.net/en/acura-rlx-model-1982
# Requesting: https://www.auto-data.net/en/acura-rlx-model-1982
# Requesting: https://www.auto-data.net/en/acura-rsx-model-141
# Requesting: https://www.auto-data.net/en/acura-rsx-model-141
# Requesting: https://www.auto-data.net/en/acura-slx-model-146
# Requesting: https://www.auto-data.net/en/acura-slx-model-146
# Requesting: https://www.auto-data.net/en/acura-tl-model-142
# Requesting: https://www.auto-data.net/en/acura-tl-model-142
# Requesting: https://www.auto-data.net/en/acura-tlx-model-2241
# Requesting: https://www.auto-data.net/en/acura-tlx-model-2241
# Requesting: https://www.auto-data.net/en/acura-tsx-model-147
# Requesting: https://www.auto-data.net/en/acura-tsx-model-147
# Requesting: https://www.auto-data.net/en/acura-zdx-model-1995
# Requesting: https://www.auto-data.net/en/acura-zdx-model-1995
# Requesting: https://www.auto-data.net/en/alfa-romeo-145-model-174
# Requesting: https://www.auto-data.net/en/alfa-romeo-145-model-174
# Requesting: https://www.auto-data.net/en/alfa-romeo-146-model-179
# Requesting: https://www.auto-data.net/en/alfa-romeo-146-model-179
# Requesting: https://www.auto-data.net/en/alfa-romeo-147-model-184
# Requesting: https://www.auto-data.net/en/alfa-romeo-147-model-184
# Requesting: https://www.auto-data.net/en/alfa-romeo-155-model-189
# Requesting: https://www.auto-data.net/en/alfa-romeo-junior-model-3429
# Requesting: https://www.auto-data.net/en/alfa-romeo-junior-model-3429
# Requesting: https://www.auto-data.net/en/alfa-romeo-mito-model-178
# Requesting: https://www.auto-data.net/en/alfa-romeo-mito-model-178
# Requesting: https://www.auto-data.net/en/alfa-romeo-montreal-model-183
# Requesting: https://www.auto-data.net/en/alfa-romeo-montreal-model-183
# Requesting: https://www.auto-data.net/en/alfa-romeo-rz-model-188
# Requesting: https://www.auto-data.net/en/alfa-romeo-rz-model-188
# Requesting: https://www.auto-data.net/en/alfa-romeo-spider-model-193
# Requesting: https://www.auto-data.net/en/alfa-romeo-spider-model-193
# Requesting: https://www.auto-data.net/en/alfa-romeo-stelvio-model-2208
# Requesting: https://www.auto-data.net/en/alfa-romeo-stelvio-model-2208
# Requesting: https://www.auto-data.net/en/alfa-romeo-sz-model-198
# Requesting: https://www.auto-data.net/en/alfa-romeo-sz-model-198
# Requesting: https://www.auto-data.net/en/alfa-romeo-tonale-model-2660
# Requesting: https://www.auto-data.net/en/alfa-romeo-tonale-model-2660
# Requesting: https://www.auto-data.net/en/alpina-b10-model-214
# Requesting: https://www.auto-data.net/en/alpina-b10-model-214
# Requesting: https://www.auto-data.net/en/alpina-b11-model-219
# Requesting: https://www.auto-data.net/en/alpina-b11-model-219
# Requesting: https://www.auto-data.net/en/alpina-b12-model-224
# Requesting: https://www.auto-data.net/en/alpina-b12-model-224
# Requesting: https://www.auto-data.net/en/alpina-b3-model-229
# Requesting: https://www.auto-data.net/en/alpina-b3-model-229
# Requesting: https://www.auto-data.net/en/alpina-b4-model-2125
# Requesting: https://www.auto-data.net/en/alpina-b4-model-2125
# Requesting: https://www.auto-data.net/en/alpina-b5-model-215
# Requesting: https://www.auto-data.net/en/alpina-b5-model-215
# Requesting: https://www.auto-data.net/en/alpina-b6-model-220
# Requesting: https://www.auto-data.net/en/alpina-b6-model-220
# Requesting: https://www.auto-data.net/en/alpina-b7-model-225
# Requesting: https://www.auto-data.net/en/alpina-b7-model-225
# Requesting: https://www.auto-data.net/en/alpina-b8-model-216
# Requesting: https://www.auto-data.net/en/alpina-b8-model-216
# Requesting: https://www.auto-data.net/en/alpina-b9-model-221
# Requesting: https://www.auto-data.net/en/alpina-b9-model-221
# Requesting: https://www.auto-data.net/en/alpina-c1-model-226
# Requesting: https://www.auto-data.net/en/alpina-c1-model-226
# Requesting: https://www.auto-data.net/en/alpina-c2-model-217
# Requesting: https://www.auto-data.net/en/alpina-c2-model-217
# Requesting: https://www.auto-data.net/en/alpina-d10-model-222
# Requesting: https://www.auto-data.net/en/alpina-d10-model-222
# Requesting: https://www.auto-data.net/en/alpina-d3-model-227
# Requesting: https://www.auto-data.net/en/alpina-d3-model-227
# Requesting: https://www.auto-data.net/en/alpina-d4-model-2124
# Requesting: https://www.auto-data.net/en/alpina-d4-model-2124
# Requesting: https://www.auto-data.net/en/alpina-d5-model-1997
# Requesting: https://www.auto-data.net/en/alpina-d5-model-1997
# Requesting: https://www.auto-data.net/en/cadillac-eldorado-model-1242
# Requesting: https://www.auto-data.net/en/cadillac-elr-model-2247
# Requesting: https://www.auto-data.net/en/cadillac-elr-model-2247
# Requesting: https://www.auto-data.net/en/cadillac-escalade-model-1247
# Requesting: https://www.auto-data.net/en/cadillac-escalade-model-1247
# Requesting: https://www.auto-data.net/en/cadillac-fleetwood-model-1238
# Requesting: https://www.auto-data.net/en/cadillac-fleetwood-model-1238
# Requesting: https://www.auto-data.net/en/cadillac-gt4-model-3303
# Requesting: https://www.auto-data.net/en/cadillac-gt4-model-3303
# Requesting: https://www.auto-data.net/en/cadillac-lse-model-1243
# Requesting: https://www.auto-data.net/en/cadillac-lse-model-1243
# Requesting: https://www.auto-data.net/en/cadillac-lyriq-model-2921
# Requesting: https://www.auto-data.net/en/cadillac-lyriq-model-2921
# Requesting: https://www.auto-data.net/en/cadillac-optiq-model-3506
# Requesting: https://www.auto-data.net/en/cadillac-optiq-model-3506
# Requesting: https://www.auto-data.net/en/cadillac-seville-model-1248
# Requesting: https://www.auto-data.net/en/cadillac-seville-model-1248
# Requesting: https://www.auto-data.net/en/cadillac-sixteen-model-2942
# Requesting: https://www.auto-data.net/en/cadillac-sixteen-model-2942
# Requesting: https://www.auto-data.net/en/cadillac-srx-model-1239
# Requesting: https://www.auto-data.net/en/cadillac-srx-model-1239
# Requesting: https://www.auto-data.net/en/cadillac-sts-model-1244
# Requesting: https://www.auto-data.net/en/cadillac-sts-model-1244
# Requesting: https://www.auto-data.net/en/cadillac-vistiq-model-3531
# Requesting: https://www.auto-data.net/en/cadillac-vistiq-model-3531
# Requesting: https://www.auto-data.net/en/cadillac-xlr-model-1249
# Requesting: https://www.auto-data.net/en/cadillac-xlr-model-1249
# Requesting: https://www.auto-data.net/en/cadillac-xt4-model-2408
# Requesting: https://www.auto-data.net/en/cadillac-xt4-model-2408
# Requesting: https://www.auto-data.net/en/cadillac-xt5-model-2165
# Requesting: https://www.auto-data.net/en/cadillac-xt5-model-2165
# Requesting: https://www.auto-data.net/en/cadillac-xt6-model-2602
# Requesting: https://www.auto-data.net/en/cadillac-xt6-model-2602
# Requesting: https://www.auto-data.net/en/cadillac-xts-model-2246
# Requesting: https://www.auto-data.net/en/cadillac-xts-model-2246
# Requesting: https://www.auto-data.net/en/chevrolet-agile-model-2604
# Requesting: https://www.auto-data.net/en/chevrolet-agile-model-2604
# Requesting: https://www.auto-data.net/en/chevrolet-alero-model-1568
# Requesting: https://www.auto-data.net/en/chevrolet-alero-model-1568
# Requesting: https://www.auto-data.net/en/chevrolet-astra-model-1573
# Requesting: https://www.auto-data.net/en/chevrolet-astra-model-1573
# Requesting: https://www.auto-data.net/en/chevrolet-astro-model-1578
# Requesting: https://www.auto-data.net/en/chevrolet-astro-model-1578
# Requesting: https://www.auto-data.net/en/chevrolet-avalanche-model-1583
# Requesting: https://www.auto-data.net/en/chevrolet-avalanche-model-1583
# Requesting: https://www.auto-data.net/en/chevrolet-aveo-model-1588
# Requesting: https://www.auto-data.net/en/chevrolet-prizm-model-1586
# Requesting: https://www.auto-data.net/en/chevrolet-prizm-model-1586
# Requesting: https://www.auto-data.net/en/chevrolet-rezzo-model-1591
# Requesting: https://www.auto-data.net/en/chevrolet-rezzo-model-1591
# Requesting: https://www.auto-data.net/en/chevrolet-s-10-pickup-model-1596
# Requesting: https://www.auto-data.net/en/chevrolet-s-10-pickup-model-1596
# Requesting: https://www.auto-data.net/en/chevrolet-sail-s-rv-model-1601
# Requesting: https://www.auto-data.net/en/chevrolet-sail-s-rv-model-1601
# Requesting: https://www.auto-data.net/en/chevrolet-seeker-model-3387
# Requesting: https://www.auto-data.net/en/chevrolet-seeker-model-3387
# Requesting: https://www.auto-data.net/en/chevrolet-silverado-1500-model-1606
# Requesting: https://www.auto-data.net/en/chevrolet-silverado-1500-model-1606
# Requesting: https://www.auto-data.net/en/chevrolet-silverado-2500-hd-model-3230
# Requesting: https://www.auto-data.net/en/chevrolet-silverado-2500-hd-model-3230
# Requesting: https://www.auto-data.net/en/chevrolet-silverado-3500-hd-model-3229
# Requesting: https://www.auto-data.net/en/chevrolet-silverado-3500-hd-model-3229
# Requesting: https://www.auto-data.net/en/chevrolet-silverado-ev-model-3533
# Requesting: https://www.auto-data.net/en/chevrolet-silverado-ev-model-3533
# Requesting: https://www.auto-data.net/en/chevrolet-sonic-model-2466
# Requesting: https://www.auto-data.net/en/chevrolet-sonic-model-2466
# Requesting: https://www.auto-data.net/en/chevrolet-spark-model-1611
# Requesting: https://www.auto-data.net/en/chevrolet-spark-model-1611
# Requesting: https://www.auto-data.net/en/chevrolet-spin-model-3049
# Requesting: https://www.auto-data.net/en/chevrolet-spin-model-3049
# Requesting: https://www.auto-data.net/en/chevrolet-ss-model-2764
# Requesting: https://www.auto-data.net/en/chevrolet-ss-model-2764
# Requesting: https://www.auto-data.net/en/chevrolet-ssr-model-1616
# Requesting: https://www.auto-data.net/en/chevrolet-ssr-model-1616
# Requesting: https://www.auto-data.net/en/chevrolet-starcraft-model-1621
# Requesting: https://www.auto-data.net/en/chevrolet-starcraft-model-1621
# Requesting: https://www.auto-data.net/en/chevrolet-suburban-model-1626
# Requesting: https://www.auto-data.net/en/chevrolet-suburban-model-1626
# Requesting: https://www.auto-data.net/en/chevrolet-tahoe-model-1572
# Requesting: https://www.auto-data.net/en/chevrolet-tahoe-model-1572
# Requesting: https://www.auto-data.net/en/chevrolet-tavera-model-1577
# Requesting: https://www.auto-data.net/en/chevrolet-tavera-model-1577
# Requesting: https://www.auto-data.net/en/chevrolet-tracker-model-1582
# ...
#  {'brand': 'bmw',
#   'model': 'bmw i8 roadster (i15)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-i8-roadster-i15-generation-6017',
#   'variant_title': '2018 BMW i8 Roadster (I15)',
#   'variant_id': '6017'},
#  {'brand': 'bmw',
#   'model': 'bmw i8 coupe (i12 lci)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-i8-coupe-i12-lci-generation-6016',
#   'variant_title': '2018 BMW i8 Coupe (I12 LCI)',
#   'variant_id': '6016'},
#  {'brand': 'bmw',
#   'model': 'bmw i8 coupe (i12)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-i8-coupe-i12-generation-4222',
#   'variant_title': '2014 BMW i8 Coupe (I12)',
#   'variant_id': '4222'},
#  {'brand': 'bmw',
#   'model': 'bmw i8 coupe concept',
#   'variant_url': 'https://www.auto-data.net/en/bmw-i8-coupe-concept-generation-6019',
#   'variant_title': '2011 BMW i8 Coupe concept',
#   'variant_id': '6019'},
#  {'brand': 'bmw',
#   'model': 'bmw isetta',
#   'variant_url': 'https://www.auto-data.net/en/bmw-isetta-generation-8608',
#   'variant_title': '1955 BMW Isetta',
#   'variant_id': '8608'},
#  {'brand': 'bmw',
#   'model': 'bmw ix (i20 lci, facelift 2025)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-ix-i20-lci-facelift-2025-generation-10351',
#   'variant_title': '2026 BMW iX (i20 LCI, facelift 2025)',
#   'variant_id': '10351'},
#  {'brand': 'bmw',
#   'model': 'bmw ix (i20)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-ix-i20-generation-8337',
#   'variant_title': '2022 BMW iX (i20)',
#   'variant_id': '8337'},
#  {'brand': 'bmw',
#   'model': 'bmw ix1 (u11)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-ix1-u11-generation-8898',
#   'variant_title': '2021 BMW iX1 (U11)',
#   'variant_id': '8898'},
#  {'brand': 'bmw',
#   'model': 'bmw ix2 (u10)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-ix2-u10-generation-9685',
#   'variant_title': '2024 BMW iX2 (U10)',
#   'variant_id': '9685'},
#  {'brand': 'bmw',
#   'model': 'bmw ix3 (g08, facelift 2021)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-ix3-g08-facelift-2021-generation-8530',
#   'variant_title': '2022 BMW iX3 (G08, facelift 2021)',
#   'variant_id': '8530'},
#  {'brand': 'bmw',
#   'model': 'bmw ix3 (g08)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-ix3-g08-generation-7890',
#   'variant_title': '2021 BMW iX3 (G08)',
#   'variant_id': '7890'},
#  {'brand': 'bmw',
#   'model': 'bmw ix3 concept',
#   'variant_url': 'https://www.auto-data.net/en/bmw-ix3-concept-generation-7891',
#   'variant_title': '2020 BMW iX3 Concept',
#   'variant_id': '7891'},
#  {'brand': 'bmw',
#   'model': 'bmw ix5 hydrogen',
#   'variant_url': 'https://www.auto-data.net/en/bmw-ix5-hydrogen-generation-8542',
#   'variant_title': '2022 BMW iX5 Hydrogen',
#   'variant_id': '8542'},
#  {'brand': 'bmw',
#   'model': 'bmw m1 (e26)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m1-e26-generation-8510',
#   'variant_title': '1978 BMW M1 (E26)',
#   'variant_id': '8510'},
#  {'brand': 'bmw',
#   'model': 'bmw m2 (g87)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m2-g87-generation-9054',
#   'variant_title': '2023 BMW M2 (G87)',
#   'variant_id': '9054'},
#  {'brand': 'bmw',
#   'model': 'bmw m2 coupe (f87)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m2-coupe-f87-generation-4694',
#   'variant_title': '2015 BMW M2 coupe (F87)',
#   'variant_id': '4694'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 touring (g81 lci, facelift 2024)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-touring-g81-lci-facelift-2024-generation-10035',
#   'variant_title': '2025 BMW M3 Touring (G81 LCI, facelift 2024)',
#   'variant_id': '10035'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 (g80 lci, facelift 2024)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-g80-lci-facelift-2024-generation-10034',
#   'variant_title': '2025 BMW M3 (G80 LCI, facelift 2024)',
#   'variant_id': '10034'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 touring (g81)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-touring-g81-generation-8930',
#   'variant_title': '2022 BMW M3 Touring (G81)',
#   'variant_id': '8930'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 (g80)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-g80-generation-7930',
#   'variant_title': '2021 BMW M3 (G80)',
#   'variant_id': '7930'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 (f80)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-f80-generation-4256',
#   'variant_title': '2014 BMW M3 (F80)',
#   'variant_id': '4256'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 convertible (e93 lci, facelift 2010)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-convertible-e93-lci-facelift-2010-generation-10169',
#   'variant_title': '2011 BMW M3 Convertible (E93 LCI, facelift 2010)',
#   'variant_id': '10169'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 coupe (e92 lci, facelift 2010)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-coupe-e92-lci-facelift-2010-generation-10168',
#   'variant_title': '2011 BMW M3 Coupe (E92 LCI, facelift 2010)',
#   'variant_id': '10168'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 (e90 lci, facelift 2008)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-e90-lci-facelift-2008-generation-2000',
#   'variant_title': '2009 BMW M3 (E90 LCI, facelift 2008)',
#   'variant_id': '2000'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 convertible (e93)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-convertible-e93-generation-2001',
#   'variant_title': '2008 BMW M3 Convertible (E93)',
#   'variant_id': '2001'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 (e90)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-e90-generation-10170',
#   'variant_title': '2008 BMW M3 (E90)',
#   'variant_id': '10170'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 coupe (e92)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-coupe-e92-generation-2003',
#   'variant_title': '2007 BMW M3 Coupe (E92)',
#   'variant_id': '2003'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 convertible (e46)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-convertible-e46-generation-2008',
#   'variant_title': '2001 BMW M3 Convertible (E46)',
#   'variant_id': '2008'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 coupe (e46)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-coupe-e46-generation-2007',
#   'variant_title': '2000 BMW M3 Coupe (E46)',
#   'variant_id': '2007'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 (e36)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-e36-generation-8945',
#   'variant_title': '1995 BMW M3 (E36)',
#   'variant_id': '8945'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 convertible (e36)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-convertible-e36-generation-2010',
#   'variant_title': '1994 BMW M3 Convertible (E36)',
#   'variant_id': '2010'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 coupe (e36)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-coupe-e36-generation-2011',
#   'variant_title': '1992 BMW M3 Coupe (E36)',
#   'variant_id': '2011'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 convertible (e30)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-convertible-e30-generation-2014',
#   'variant_title': '1988 BMW M3 Convertible (E30)',
#   'variant_id': '2014'},
#  {'brand': 'bmw',
#   'model': 'bmw m3 coupe (e30)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m3-coupe-e30-generation-2015',
#   'variant_title': '1986 BMW M3 Coupe (E30)',
#   'variant_id': '2015'},
#  {'brand': 'bmw',
#   'model': 'bmw m4 convertible (g83 lci, facelift 2024)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m4-convertible-g83-lci-facelift-2024-generation-9867',
#   'variant_title': '2025 BMW M4 Convertible (G83 LCI, facelift 2024)',
#   'variant_id': '9867'},
#  {'brand': 'bmw',
#   'model': 'bmw m4 (g82 lci, facelift 2024)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m4-g82-lci-facelift-2024-generation-9864',
#   'variant_title': '2025 BMW M4 (G82 LCI, facelift 2024)',
#   'variant_id': '9864'},
#  {'brand': 'bmw',
#   'model': 'bmw m4 convertible (g83)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m4-convertible-g83-generation-8373',
#   'variant_title': '2021 BMW M4 Convertible (G83)',
#   'variant_id': '8373'},
#  {'brand': 'bmw',
#   'model': 'bmw m4 (g82)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m4-g82-generation-7929',
#   'variant_title': '2021 BMW M4 (G82)',
#   'variant_id': '7929'},
#  {'brand': 'bmw',
#   'model': 'bmw m4 convertible (f83)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m4-convertible-f83-generation-4264',
#   'variant_title': '2014 BMW M4 Convertible (F83)',
#   'variant_id': '4264'},
#  {'brand': 'bmw',
#   'model': 'bmw m4 (f82)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m4-f82-generation-4257',
#   'variant_title': '2014 BMW M4 (F82)',
#   'variant_id': '4257'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 touring (g91)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-touring-g91-generation-10139',
#   'variant_title': '2025 BMW M5 Touring (G91)',
#   'variant_id': '10139'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 (g90)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-g90-generation-10076',
#   'variant_title': '2025 BMW M5 (G90)',
#   'variant_id': '10076'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 (f90 lci, facelift 2020)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-f90-lci-facelift-2020-generation-7831',
#   'variant_title': '2021 BMW M5 (F90 LCI, facelift 2020)',
#   'variant_id': '7831'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 (f90)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-f90-generation-5548',
#   'variant_title': '2017 BMW M5 (F90)',
#   'variant_id': '5548'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 (f10m lci, facelift 2013)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-f10m-lci-facelift-2013-generation-5092',
#   'variant_title': '2014 BMW M5 (F10M LCI, facelift 2013)',
#   'variant_id': '5092'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 (f10m)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-f10m-generation-3917',
#   'variant_title': '2011 BMW M5 (F10M)',
#   'variant_id': '3917'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 touring (e61 lci, facelift 2007)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-touring-e61-lci-facelift-2007-generation-2002',
#   'variant_title': '2008 BMW M5 Touring (E61 LCI, facelift 2007)',
#   'variant_id': '2002'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 (e60 lci, facelift 2007)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-e60-lci-facelift-2007-generation-8903',
#   'variant_title': '2008 BMW M5 (E60 LCI, facelift 2007)',
#   'variant_id': '8903'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 (e60)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-e60-generation-2006',
#   'variant_title': '2005 BMW M5 (E60)',
#   'variant_id': '2006'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 (e39 lci, facelift 2000)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-e39-lci-facelift-2000-generation-8983',
#   'variant_title': '2001 BMW M5 (E39 LCI, facelift 2000)',
#   'variant_id': '8983'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 (e39)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-e39-generation-2009',
#   'variant_title': '1998 BMW M5 (E39)',
#   'variant_id': '2009'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 touring (e34)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-touring-e34-generation-2012',
#   'variant_title': '1992 BMW M5 Touring (E34)',
#   'variant_id': '2012'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 (e34)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-e34-generation-2013',
#   'variant_title': '1988 BMW M5 (E34)',
#   'variant_id': '2013'},
#  {'brand': 'bmw',
#   'model': 'bmw m5 (e28)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m5-e28-generation-2016',
#   'variant_title': '1984 BMW M5 (E28)',
#   'variant_id': '2016'},
#  {'brand': 'bmw',
#   'model': 'bmw m6 gran coupe (f06m lci, facelift 2014)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m6-gran-coupe-f06m-lci-facelift-2014-generation-6248',
#   'variant_title': '2014 BMW M6 Gran Coupe (F06M LCI, facelift 2014)',
#   'variant_id': '6248'},
#  {'brand': 'bmw',
#   'model': 'bmw m6 convertible (f12m, lci, facelift 2014)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m6-convertible-f12m-lci-facelift-2014-generation-6249',
#   'variant_title': '2014 BMW M6 Convertible (F12M, LCI, facelift 2014)',
#   'variant_id': '6249'},
#  {'brand': 'bmw',
#   'model': 'bmw m6 coupe (f13m lci, facelift 2014)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m6-coupe-f13m-lci-facelift-2014-generation-4951',
#   'variant_title': '2014 BMW M6 Coupe (F13M LCI, facelift 2014)',
#   'variant_id': '4951'},
#  {'brand': 'bmw',
#   'model': 'bmw m6 gran coupe (f06m)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m6-gran-coupe-f06m-generation-6250',
#   'variant_title': '2013 BMW M6 Gran Coupe (F06M)',
#   'variant_id': '6250'},
#  {'brand': 'bmw',
#   'model': 'bmw m6 convertible (f12m)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m6-convertible-f12m-generation-3919',
#   'variant_title': '2012 BMW M6 Convertible (F12M)',
#   'variant_id': '3919'},
#  {'brand': 'bmw',
#   'model': 'bmw m6 coupe (f13m)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m6-coupe-f13m-generation-3918',
#   'variant_title': '2012 BMW M6 Coupe (F13M)',
#   'variant_id': '3918'},
#  {'brand': 'bmw',
#   'model': 'bmw m6 convertible (e64 lci, facelift 2007)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m6-convertible-e64-lci-facelift-2007-generation-8278',
#   'variant_title': '2008 BMW M6 Convertible (E64 LCI, facelift 2007)',
#   'variant_id': '8278'},
#  {'brand': 'bmw',
#   'model': 'bmw m6 (e63 lci, facelift 2007)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m6-e63-lci-facelift-2007-generation-8277',
#   'variant_title': '2008 BMW M6 (E63 LCI, facelift 2007)',
#   'variant_id': '8277'},
#  {'brand': 'bmw',
#   'model': 'bmw m6 convertible (e64)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m6-convertible-e64-generation-2004',
#   'variant_title': '2006 BMW M6 Convertible (E64)',
#   'variant_id': '2004'},
#  {'brand': 'bmw',
#   'model': 'bmw m6 (e63)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m6-e63-generation-2005',
#   'variant_title': '2005 BMW M6 (E63)',
#   'variant_id': '2005'},
#  {'brand': 'bmw',
#   'model': 'bmw m8 gran coupe (f93, facelift 2022)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m8-gran-coupe-f93-facelift-2022-generation-8780',
#   'variant_title': '2022 BMW M8 Gran Coupe (F93, facelift 2022)',
#   'variant_id': '8780'},
#  {'brand': 'bmw',
#   'model': 'bmw m8 coupe (f92, facelift 2022)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m8-coupe-f92-facelift-2022-generation-8779',
#   'variant_title': '2022 BMW M8 Coupe (F92, facelift 2022)',
#   'variant_id': '8779'},
#  {'brand': 'bmw',
#   'model': 'bmw m8 convertible (f91, facelift 2022)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m8-convertible-f91-facelift-2022-generation-8778',
#   'variant_title': '2022 BMW M8 Convertible (F91, facelift 2022)',
#   'variant_id': '8778'},
#  {'brand': 'bmw',
#   'model': 'bmw m8 gran coupe (f93)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m8-gran-coupe-f93-generation-7331',
#   'variant_title': '2019 BMW M8 Gran Coupe (F93)',
#   'variant_id': '7331'},
#  {'brand': 'bmw',
#   'model': 'bmw m8 coupe (f92)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m8-coupe-f92-generation-7169',
#   'variant_title': '2019 BMW M8 Coupe (F92)',
#   'variant_id': '7169'},
#  {'brand': 'bmw',
#   'model': 'bmw m8 convertible (f91)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m8-convertible-f91-generation-7266',
#   'variant_title': '2019 BMW M8 Convertible (F91)',
#   'variant_id': '7266'},
#  {'brand': 'bmw',
#   'model': 'bmw m8 gran coupe (concept)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m8-gran-coupe-concept-generation-6045',
#   'variant_title': '2017 BMW M8 Gran Coupe (Concept)',
#   'variant_id': '6045'},
#  {'brand': 'bmw',
#   'model': 'bmw m8 coupe prototype (e31)',
#   'variant_url': 'https://www.auto-data.net/en/bmw-m8-coupe-prototype-e31-generation-8607',
#   'variant_title': '1992 BMW M8 Coupe Prototype (E31)',
#   'variant_id': '8607'},
#  {'brand': 'bmw',
#   'model': 'bmw new class coupe',
#   'variant_url': 'https://www.auto-data.net/en/bmw-new-class-coupe-generation-8468',
#   'variant_title': '1965 BMW New Class Coupe',
#   'variant_id': '8468'},
#  ...]

# %%
from collections import defaultdict
import requests
import time
import re
import pandas as pd
from bs4 import BeautifulSoup

# --- Get fuel type & transmission from spec page ---
def get_fuel_and_transmission(spec_url):
    try:
        response = requests.get(spec_url, headers={
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
        })
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        fuel_type = ''
        transmission = ''

        for row in soup.find_all('tr'):
            th = row.find('th')
            td = row.find('td')
            if th and td:
                label = th.text.strip()
                value = td.text.strip()

                if label == 'Fuel Type':
                    fuel_type = value
                elif 'Number of gears and type of gearbox' in label:
                    transmission = value

        return fuel_type, transmission

    except Exception as e:
        print(f"Error in spec URL {spec_url}: {e}")
        return '', ''

# --- Main variant page scraper ---
def extract_specs_links(variant_url, variant_title):
    try:
        time.sleep(1)

        response = requests.get(variant_url, headers={
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
        })
        response.raise_for_status()

        soup = BeautifulSoup(response.text, 'html.parser')
        specs_links = []

        for th in soup.find_all('th', class_='i'):
            link = th.find('a', href=True)
            if not link:
                continue

            href = link['href']
            visible_text = link.text.strip()
            spec_url = 'https://www.auto-data.net' + href + '/tech'

            # Extract year from variant title
            year_match = re.search(r'\b(19|20)\d{2}\b', variant_title)
            year = year_match.group(0) if year_match else "Unknown"

            # Get fuel & transmission from the /tech page
            fuel, trans = get_fuel_and_transmission(spec_url)

            specs_links.append({
                'brand': variant_title.split()[0],
                'year': year,
                'spec_title': visible_text,
                'spec_url': spec_url,
                'fuel_type': fuel,
                'transmission': trans
            })

        return specs_links

    except Exception as e:
        print(f"Error processing {variant_url}: {str(e)}")
        return []

# --- Run it across a list of variants with brand limit ---
def process_variants_for_specs(variants_list, limit_per_brand=3):
    all_specs = []
    brand_counts = defaultdict(int)

    for variant in variants_list:
        brand = variant['brand'].lower()
        if brand_counts[brand] >= limit_per_brand:
            continue

        print(f"Processing specs for {variant['variant_title']}...")
        specs = extract_specs_links(variant['variant_url'], variant['variant_title'])
        all_specs.extend(specs)
        brand_counts[brand] += 1
        print(f"Found {len(specs)} specs for {variant['variant_title']}")

    return all_specs

# --- Run ---
spec_links = process_variants_for_specs(variant_links, limit_per_brand=3)

spec_df = pd.DataFrame(spec_links, columns=[
    'brand', 'year', 'spec_title', 'spec_url', 'fuel_type', 'transmission'
])
spec_df.to_csv('data/cars-data-spec-links-table.csv', index=False)
# Out:
# Processing specs for 2025 Acura ADX...
# Found 1 specs for 2025 Acura ADX
# Processing specs for 2001 Acura CL II...
# Found 3 specs for 2001 Acura CL II
# Processing specs for 1997 Acura CL...
# Found 3 specs for 1997 Acura CL
# Processing specs for 1999 Alfa Romeo 145 (930, facelift 1999)...
# Found 5 specs for 1999 Alfa Romeo 145 (930, facelift 1999)
# Processing specs for 1997 Alfa Romeo 145 (930, facelift 1997)...
# Found 7 specs for 1997 Alfa Romeo 145 (930, facelift 1997)
# Processing specs for 1994 Alfa Romeo 145 (930)...
# Found 5 specs for 1994 Alfa Romeo 145 (930)
# Processing specs for 1997 Alpina B10 Touring (E39)...
# Found 4 specs for 1997 Alpina B10 Touring (E39)
# Processing specs for 1997 Alpina B10 (E39)...
# Found 5 specs for 1997 Alpina B10 (E39)
# Processing specs for 1993 Alpina B10 Touring (E34)...
# Found 3 specs for 1993 Alpina B10 Touring (E34)
# Processing specs for 1972 Aston Martin AMV8 Volante...
# Found 6 specs for 1972 Aston Martin AMV8 Volante
# Processing specs for 1972 Aston Martin AMV8...
# Found 6 specs for 1972 Aston Martin AMV8
# Processing specs for 1980 Aston Martin Bulldog...
# Found 1 specs for 1980 Aston Martin Bulldog
# Processing specs for 1990 Audi 100 Avant (4A,C4)...
# Found 20 specs for 1990 Audi 100 Avant (4A,C4)
# Processing specs for 1990 Audi 100 (4A,C4)...
# Found 20 specs for 1990 Audi 100 (4A,C4)
# Processing specs for 1988 Audi 100 Avant (C3, Typ 44, 44Q, facelift 1988)...
# Found 16 specs for 1988 Audi 100 Avant (C3, Typ 44, 44Q, facelift 1988)
# Processing specs for 2002 Bentley Arnage R...
# Found 2 specs for 2002 Bentley Arnage R
# Processing specs for 2002 Bentley Arnage T...
# Found 2 specs for 2002 Bentley Arnage T
# Processing specs for 1998 Bentley Arnage I...
# Found 2 specs for 1998 Bentley Arnage I
# Processing specs for 1966 BMW 02 (E10)...
# Found 9 specs for 1966 BMW 02 (E10)
# Processing specs for 2025 BMW 1 Series Hatchback (F70)...
# Found 6 specs for 2025 BMW 1 Series Hatchback (F70)
# Processing specs for 2019 BMW 1 Series Hatchback (F40)...
# Processing specs for 2016 Volkswagen Amarok I Double Cab (facelift 2016)...
# Found 5 specs for 2016 Volkswagen Amarok I Double Cab (facelift 2016)
# Processing specs for 1968 Volvo 140 Combi (145)...
# Found 5 specs for 1968 Volvo 140 Combi (145)
# Processing specs for 1966 Volvo 140 (142,144)...
# Found 7 specs for 1966 Volvo 140 (142,144)
# Processing specs for 1969 Volvo 164...
# Found 2 specs for 1969 Volvo 164

# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, as_completed
from collections import defaultdict
import time

# Configure session with retries and timeouts
session = requests.Session()
adapter = requests.adapters.HTTPAdapter(
    max_retries=3,
    pool_connections=100,
    pool_maxsize=100
)
session.mount('http://', adapter)
session.mount('https://', adapter)
session.headers.update({
    'User-Agent': 'Mozilla/5.0',
    'Accept-Encoding': 'gzip, deflate',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5',
    'Connection': 'keep-alive'
})

# Cache for storing already fetched pages
PAGE_CACHE = {}
CACHE_EXPIRY = 3600  # 1 hour in seconds

def get_cached_page(url):
    now = time.time()
    if url in PAGE_CACHE and now - PAGE_CACHE[url]['timestamp'] < CACHE_EXPIRY:
        return PAGE_CACHE[url]['content']
    try:
        response = session.get(url, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        PAGE_CACHE[url] = {
            'content': soup,
            'timestamp': now
        }
        return soup
    except Exception as e:
        print(f"Error fetching {url}: {e}")
        return None

def extract_model_name_from_generation(soup):
    generation_row = soup.find('th', string='Generation')
    if generation_row:
        generation_td = generation_row.find_next_sibling('td')
        if generation_td:
            link = generation_td.find('a')
            if link:
                return link.text.strip()
    return None

def extract_model_name_from_header(soup):
    h2 = soup.find('h2', class_='car')
    if h2:
        words = h2.text.strip().split()
        return words[1] if len(words) > 1 else 'Unknown'
    return None


def get_model_name(soup, brand=None):
    model = extract_model_name_from_generation(soup)
    if not model:
        model = extract_model_name_from_header(soup)
    return model or 'Unknown'


def parse_spec_details(soup):
    details = {
        'model': get_model_name(soup),
        'fuel_type': '', 'transmission': '', 'engine_modification': '',
        'start_production': '', 'body_type': '', 'seats': '', 'doors': '',
        'power': '', 'drive_wheel': '', 'engine_aspiration': '',
        'fuel_injection_system': '', 'number_of_cylinders': '',
        'engine_configuration': '', 'tires_size': '',
        'fuel_consumption_urban': '', 'fuel_consumption_extra_urban': ''
    }

    LABEL_MAP = {
        'Fuel Type': 'fuel_type',
        'Start of production': 'start_production',
        'Drive wheel': 'drive_wheel',
        'Engine aspiration': 'engine_aspiration',
        'Fuel injection system': 'fuel_injection_system',
        'Number of cylinders': 'number_of_cylinders',
        'Engine configuration': 'engine_configuration',
        'Tires size': 'tires_size',
        'Power': 'power',
        'Modification (Engine)': 'engine_modification',
        'Number of gears and type of gearbox': 'transmission',
        'Number of seats': 'seats',
        'Seats': 'seats',
        'Number of doors': 'doors',
        'Doors': 'doors',
        'Fuel consumption (economy) - urban': 'fuel_consumption_urban',
        'Fuel consumption (economy) - extra urban': 'fuel_consumption_extra_urban',
        'Body type': 'body_type',
        'Car body': 'body_type'
    }

    for row in soup.find_all('tr'):
        th = row.find('th')
        td = row.find('td')
        if not th or not td:
            continue
        label = th.text.strip().rstrip(':')
        value = td.text.strip()
        if label in LABEL_MAP:
            details[LABEL_MAP[label]] = value

    return details

def get_spec_details(spec_url):
    try:
        soup = get_cached_page(spec_url)
        if not soup:
            return {'model': 'Unknown', **{k: '' for k in details if k != 'model'}}
        return parse_spec_details(soup)
    except Exception as e:
        print(f"Error in spec URL {spec_url}: {e}")
        return {'model': 'Unknown', **{k: '' for k in details if k != 'model'}}

def extract_years_from_content(soup):
    years = []
    keyspecs_table = soup.find('table', id='ulkey')
    if keyspecs_table:
        h3 = keyspecs_table.find('h3')
        if h3:
            years = [int(y) for y in re.findall(r'\b\d{4}\b', h3.text)]
    return years or ['Unknown']

def process_spec_link(th):
    link = th.find('a', href=True)
    if not link:
        return None
    href = link['href']
    visible_text = link.text.strip()
    spec_url = 'https://www.auto-data.net' + href + '/tech'
    return {
        'spec_title': visible_text,
        'spec_url': spec_url
    }

def extract_specs_links(variant_url, variant_title):
    try:
        soup = get_cached_page(variant_url)
        if not soup:
            return []

        brand = variant_url.split('/')[4].split('-')[0].capitalize()
        model = get_model_name(soup)
        years = extract_years_from_content(soup)

        spec_entries = []
        specs = [process_spec_link(th) for th in soup.find_all('th', class_='i')]
        specs = [s for s in specs if s is not None]

        for spec in specs:
            spec_years = years
            if years == ['Unknown']:
                title_years = [int(y) for y in re.findall(r'\b\d{4}\b', spec['spec_title'])]
                if title_years:
                    spec_years = title_years

            if len(spec_years) > 1 and ' - ' in spec['spec_title']:
                try:
                    start_year = min(spec_years)
                    end_year = max(spec_years)
                    spec_years = list(range(start_year, end_year + 1))
                except:
                    pass

            spec_entries.append({
                'brand': brand,
                'model': model,
                'years': spec_years,
                'spec_title': spec['spec_title'],
                'spec_url': spec['spec_url']
            })

        return spec_entries
    except Exception as e:
        print(f"Error processing {variant_url}: {e}")
        return []

def process_variant(variant):
    print(f"Extracting spec links: {variant['variant_title']}")
    return extract_specs_links(variant['variant_url'], variant['variant_title'])

def process_spec_entry(entry, details):
    results = []
    for year in entry['years']:
        results.append({
            'brand': entry['brand'],
            'model': details['model'],
            'year': year,
            'spec_title': entry['spec_title'],
            'spec_url': entry['spec_url'],
            **details
        })
    return results

def main():
    variant_df = pd.read_csv('data/auto-data-variants-links-table.csv')

    # Limit to 5 cars
    variant_links = variant_df.to_dict(orient='records')

    print("Extracting all spec links for 5 cars...")
    all_spec_entries = []

    with ThreadPoolExecutor(max_workers=5) as executor:
        futures = [executor.submit(process_variant, variant) for variant in variant_links]
        for future in as_completed(futures):
            try:
                all_spec_entries.extend(future.result())
            except Exception as e:
                print(f"Error processing variant: {e}")

    print(f"Fetching {len(all_spec_entries)} spec details in parallel...")
    results = []

    with ThreadPoolExecutor(max_workers=10) as executor:
        future_to_entry = {
            executor.submit(get_spec_details, entry['spec_url']): entry
            for entry in all_spec_entries
        }

        for future in as_completed(future_to_entry):
            entry = future_to_entry[future]
            try:
                details = future.result()
                results.extend(process_spec_entry(entry, details))
            except Exception as e:
                print(f"Error retrieving details: {e}")

    spec_df = pd.DataFrame(results)
    spec_df.to_csv('data/auto-data-table.csv', index=False)
    print(f"Saved: data/auto-data-table.csv with {len(spec_df)} records")

if __name__ == '__main__':
    start_time = time.time()
    main()
    print(f"Total execution time: {time.time() - start_time:.2f} seconds")
# Out:
# Extracting all spec links for 5 cars...
# Extracting spec links: 2025 Acura ADX
# Extracting spec links: 2001 Acura CL II
# Extracting spec links: 1997 Acura CL
# Extracting spec links: 2010 Acura CSX (facelift, 2009)
# Extracting spec links: 2006 Acura CSX
# Extracting spec links: 1997 Acura ELExtracting spec links: 2019 Acura ILX (facelift 2019)
#
# Extracting spec links: 2016 Acura ILX (facelift 2016)
# Extracting spec links: 2013 Acura ILX
# Extracting spec links: 2023 Acura Integra V
# Extracting spec links: 1994 Acura Integra III Sedan
# Extracting spec links: 1994 Acura Integra III Coupe
# Extracting spec links: 1990 Acura Integra II Sedan
# Extracting spec links: 1990 Acura Integra II HatchbackExtracting spec links: 1986 Acura Integra I
#
# Extracting spec links: 2025 Acura MDX IV (facelift 2024)
# Extracting spec links: 2022 Acura MDX IV
# Extracting spec links: 2017 Acura MDX III (facelift 2017)Extracting spec links: 2014 Acura MDX III
# Extracting spec links: 2007 Acura MDX II
#
# Extracting spec links: 2001 Acura MDX
# Extracting spec links: 2016 Acura NSX II
# Extracting spec links: 2002 Acura NSX I (facelift 2002)
# Extracting spec links: 1995 Acura NSX-TExtracting spec links: 1990 Acura NSX I
#
# Extracting spec links: 2022 Acura RDX III (facelift 2021)
# Extracting spec links: 2019 Acura RDX III
# Extracting spec links: 2016 Acura RDX II (facelift 2016)Extracting spec links: 2013 Acura RDX II
#
# Extracting spec links: 2010 Acura RDX I (facelift 2009)
# Extracting spec links: 2007 Acura RDX I
# Extracting spec links: 2005 Acura RL II
# Extracting spec links: 1996 Acura RL (KA964)
# Extracting spec links: 2018 Acura RLX (facelift 2017)
# Extracting spec links: 2014 Acura RLX
# Extracting spec links: 2002 Acura RSX
# Extracting spec links: 1996 Acura SLX
# Extracting spec links: 2012 Acura TL IV (facelift 2012)
# Extracting spec links: 2009 Acura TL IV (UA8/9)
# Extracting spec links: 2004 Acura TL III (UA6/7)
# Extracting spec links: 1999 Acura TL II (UA5)
# Extracting spec links: 1996 Acura TL I (UA2)
# Extracting spec links: 2024 Acura TLX II (facelift 2023)
# Extracting spec links: 2021 Acura TLX II
# Extracting spec links: 2018 Acura TLX I (facelift 2017)
# Extracting spec links: 2015 Acura TLX I
# Extracting spec links: 2011 Acura TSX (facelift)
# Extracting spec links: 2011 Acura TSX Sport Wagon
# Extracting spec links: 2009 Acura TSX II (Cu2)
# Extracting spec links: 2004 Acura TSX I (CL9)
# Extracting spec links: 2024 Acura ZDX II
# Extracting spec links: 2010 Acura ZDX I
# Extracting spec links: 1999 Alfa Romeo 145 (930, facelift 1999)
# Extracting spec links: 1997 Alfa Romeo 145 (930, facelift 1997)
# Extracting spec links: 1994 Alfa Romeo 145 (930)
# Extracting spec links: 1999 Alfa Romeo 146 (930, facelift 1999)
# Extracting spec links: 1997 Alfa Romeo 146 (930, facelift 1997)
# Extracting spec links: 1995 Alfa Romeo 146 (930)
# Extracting spec links: 2004 Alfa Romeo 147 (facelift 2004) 5-doors
# Extracting spec links: 2004 Alfa Romeo 147 (facelift 2004) 3-doors
# Extracting spec links: 2004 Alfa Romeo 147 GTA
# Extracting spec links: 2001 Alfa Romeo 147 5-doors
# Extracting spec links: 2001 Alfa Romeo 147 3-doors
# Extracting spec links: 1992 Alfa Romeo 155 (167)
# Extracting spec links: 2004 Alfa Romeo 156 Crosswagon (932, facelift 2003)
# Extracting spec links: 2003 Alfa Romeo 156 (932, facelift 2003)
# Extracting spec links: 2003 Alfa Romeo 156 Sport Wagon (932, facelift 2003)
# Extracting spec links: 2002 Alfa Romeo 156 GTA Sport Wagon (932)
# Extracting spec links: 2002 Alfa Romeo 156 GTA (932)
# Extracting spec links: 2000 Alfa Romeo 156 Sport Wagon (932)
# Extracting spec links: 1997 Alfa Romeo 156 (932)
# Extracting spec links: 2006 Alfa Romeo 159 Sportwagon
# Extracting spec links: 2005 Alfa Romeo 159
# Extracting spec links: 1987 Alfa Romeo 164 (164)
# Extracting spec links: 2003 Alfa Romeo 166 (936, facelift 2003)
# Extracting spec links: 1998 Alfa Romeo 166 (936)
# Extracting spec links: 1968 Alfa Romeo 1750-2000
# Extracting spec links: 1990 Alfa Romeo 33 Sport Wagon (907B)
# Extracting spec links: 1990 Alfa Romeo 33 (907A)
# Extracting spec links: 1983 Alfa Romeo 33 Sport Wagon (905A)
# Extracting spec links: 1983 Alfa Romeo 33 (905)
# Extracting spec links: 1967 Alfa Romeo 33 Stradale
# Extracting spec links: 2024 Alfa Romeo 33 Stradale (2023)
# Extracting spec links: 2017 Alfa Romeo 4C  (facelift 2017)
# Extracting spec links: 2016 Alfa Romeo 4C Spider
# Extracting spec links: 2014 Alfa Romeo 4C
# Extracting spec links: 1979 Alfa Romeo 6 (119)
# Extracting spec links: 1988 Alfa Romeo 75 (162 B, facelift 1988)
# Extracting spec links: 1985 Alfa Romeo 75 (162 B)
# Extracting spec links: 2008 Alfa Romeo 8C Spider
# Extracting spec links: 2007 Alfa Romeo 8C Competizione
# Extracting spec links: 1984 Alfa Romeo 90 (162)
# Extracting spec links: 1977 Alfa Romeo Alfasud Giardinetta (904)
# Extracting spec links: 1976 Alfa Romeo Alfasud Sprint (902.A)
# Extracting spec links: 1972 Alfa Romeo Alfasud (901)
# Extracting spec links: 1972 Alfa Romeo Alfetta (116)
# Extracting spec links: 1972 Alfa Romeo Alfetta GT (116)
# Extracting spec links: 1983 Alfa Romeo Arna (920)
# Extracting spec links: 2006 Alfa Romeo Brera
# Extracting spec links: 2023 Alfa Romeo Giulia (952, facelift 2022)
# Extracting spec links: 2016 Alfa Romeo Giulia (952)
# Extracting spec links: 1965 Alfa Romeo Giulia
# Extracting spec links: 1962 Alfa Romeo Giulia ErreErre Fuoriserie
# Extracting spec links: 2017 Alfa Romeo Giulietta (Type 940 facelift 2016)
# Extracting spec links: 2011 Alfa Romeo Giulietta (Type 940)
# Extracting spec links: 1978 Alfa Romeo Giulietta (116)
# Extracting spec links: 2004 Alfa Romeo GT Coupe (937)
# Extracting spec links: 1964 Alfa Romeo GT
# Extracting spec links: 1968 Alfa Romeo GTA Coupe
# Extracting spec links: 2003 Alfa Romeo GTV (916, facelift 2003)
# Extracting spec links: 1995 Alfa Romeo GTV (916)
# Extracting spec links: 1974 Alfa Romeo GTV (116)
# Extracting spec links: 2024 Alfa Romeo Junior
# Extracting spec links: 2016 Alfa Romeo MiTo (facelift 2016)
# Extracting spec links: 2013 Alfa Romeo MiTo (facelift 2013)
# Extracting spec links: 2008 Alfa Romeo MiTo
# Extracting spec links: 1970 Alfa Romeo Montreal
# Extracting spec links: 1989 Alfa Romeo RZ
# Extracting spec links: 2006 Alfa Romeo Spider (939)
# Extracting spec links: 2003 Alfa Romeo Spider (916, facelift 2003)Extracting spec links: 1995 Alfa Romeo Spider (916)
#
# Extracting spec links: 1970 Alfa Romeo Spider (115)
# Extracting spec links: 1966 Alfa Romeo Spider (105)
# Extracting spec links: 2023 Alfa Romeo Stelvio (949, facelift 2022)
# Extracting spec links: 2017 Alfa Romeo Stelvio (949)
# Extracting spec links: 1990 Alfa Romeo SZ
# Extracting spec links: 2022 Alfa Romeo Tonale
# Extracting spec links: 2019 Alfa Romeo Tonale Concept
# Extracting spec links: 1997 Alpina B10 Touring (E39)
# Extracting spec links: 1997 Alpina B10 (E39)
# Extracting spec links: 1993 Alpina B10 Touring (E34)
# Extracting spec links: 1988 Alpina B10 (E34)
# Extracting spec links: 1987 Alpina B11 (E32)
# Extracting spec links: 1995 Alpina B12 (E38)
# Extracting spec links: 1990 Alpina B12 Coupe (E31)
# Extracting spec links: 1988 Alpina B12 (E32)
# Extracting spec links: 2025 Alpina B3 Touring (G21, facelift 2024)
# Extracting spec links: 2025 Alpina B3 Sedan (G20, facelift 2024)
# Extracting spec links: 2023 Alpina B3 Sedan (G20, facelift 2022)
# Extracting spec links: 2023 Alpina B3 Touring (G21, facelift 2022)
# Extracting spec links: 2020 Alpina B3 Sedan (G20)
# Extracting spec links: 2020 Alpina B3 Touring (G21)
# Extracting spec links: 2015 Alpina B3 (F30 LCI, Facelift 2015)
# Extracting spec links: 2015 Alpina B3 Touring (F31 LCI, Facelift 2015)
# Extracting spec links: 2013 Alpina B3 (F30)
# Extracting spec links: 2013 Alpina B3 Touring (F31)
# Extracting spec links: 2007 Alpina B3 (E90)
# Extracting spec links: 2007 Alpina B3 Cabrio (E93)
# Extracting spec links: 2007 Alpina B3 Coupe (E92)
# Extracting spec links: 1999 Alpina B3 (E46)
# Extracting spec links: 2000 Alpina B3 Cabrio (E46)
# Extracting spec links: 1999 Alpina B3 Coupe (E46)
# Extracting spec links: 1999 Alpina B3 Touring (E46)
# Extracting spec links: 1993 Alpina B3 (E36)
# Extracting spec links: 1993 Alpina B3 Coupe (E36)
# Extracting spec links: 1993 Alpina B3 Touring (E36)
# Extracting spec links: 1993 Alpina B3 Cabrio (E36)
# Extracting spec links: 1987 Alpina B3 (E30)
# Extracting spec links: 1987 Alpina B3 Cabrio (E30)
# Extracting spec links: 1987 Alpina B3 Touring (E30)
# Extracting spec links: 2025 Alpina B4 Gran Coupe (G26, facelift 2024)
# Extracting spec links: 2022 Alpina B4 Gran Coupe (G26)Extracting spec links: 2017 Alpina B4 Cabrio (facelift 2017)
# Extracting spec links: 2017 Alpina B4 Coupe (facelift 2017)
#
# Extracting spec links: 2014 Alpina B4 Cabrio
# Extracting spec links: 2014 Alpina B4 Coupe
# Extracting spec links: 2020 Alpina B5 Sedan (G30, facelift 2020)
# Extracting spec links: 2020 Alpina B5 Touring (G31, facelift 2020)
# Extracting spec links: 2017 Alpina B5 Sedan (G30)
# Extracting spec links: 2017 Alpina B5 Touring (G31)
# Extracting spec links: 2013 Alpina B5 Sedan (F10 LCI, Facelift 2013)
# Extracting spec links: 2013 Alpina B5 Touring (F11 LCI, Facelift 2013)
# Extracting spec links: 2011 Alpina B5 Sedan (F10)
# Extracting spec links: 2011 Alpina B5 Touring (F11)
# Extracting spec links: 2005 Alpina B5 (E60)
# Extracting spec links: 2005 Alpina B5 Touring (E61)
# Extracting spec links: 2015 Alpina B6 Gran Coupe (F06 LCI, Facelift 2015)
# Extracting spec links: 2015 Alpina B6 Cabrio (F12 LCI, Facelift 2015)
# Extracting spec links: 2015 Alpina B6 Coupe (F13 LCI, Facelift 2015)
# Extracting spec links: 2011 Alpina B6 Cabrio (F12)
# Extracting spec links: 2011 Alpina B6 Coupe (F13)
# Extracting spec links: 2006 Alpina B6 Coupe (E63)
# Extracting spec links: 2006 Alpina B6 Cabrio (E64)
# Extracting spec links: 1992 Alpina B6 (E36)
# Extracting spec links: 1984 Alpina B6 (E30)
# Extracting spec links: 1978 Alpina B6 (E21)
# Extracting spec links: 2019 Alpina B7 (G12, facelift 2019)
# Extracting spec links: 2016 Alpina B7 (G12)
# Extracting spec links: 2012 Alpina B7 (F02)
# Extracting spec links: 2012 Alpina B7 (F01)
# Extracting spec links: 2005 Alpina B7 (E65/E66L)
# Extracting spec links: 1984 Alpina B7 (E28)
# Extracting spec links: 1978 Alpina B7 Coupe (E24)
# Extracting spec links: 1978 Alpina B7 (E12)
# Extracting spec links: 2023 Alpina B8 Gran Coupe (G16 LCI, facelift 2022)
# Extracting spec links: 2021 Alpina B8 Gran Coupe (G16)
# Extracting spec links: 1995 Alpina B8 (E36)
# Extracting spec links: 1995 Alpina B8 Cabrio (E36)
# Extracting spec links: 1995 Alpina B8 Coupe (E36)
# Extracting spec links: 1995 Alpina B8 Touring (E36)
# Extracting spec links: 1982 Alpina B9 Coupe (E24)
# Extracting spec links: 1981 Alpina B9 (E28)
# Extracting spec links: 1983 Alpina C1 (E30)
# Extracting spec links: 1980 Alpina C1 (E21)
# Extracting spec links: 1985 Alpina C2 (E30)
# Extracting spec links: 1986 Alpina C2 Cabrio (E30)
# Extracting spec links: 2000 Alpina D10 (E39)
# Extracting spec links: 2000 Alpina D10 Touring (E39)
# Extracting spec links: 2023 Alpina D3 Sedan (G20, facelift 2022)
# Extracting spec links: 2023 Alpina D3 Touring (G21, facelift 2022)
# Extracting spec links: 2020 Alpina D3 Sedan (G20)
# Extracting spec links: 2020 Alpina D3 Touring (G21)
# Extracting spec links: 2015 Alpina D3 (F30 LCI, Facelift 2015)
# Extracting spec links: 2015 Alpina D3 Touring (F31 LCI, Facelift 2015)
# Extracting spec links: 2013 Alpina D3 (F30)
# Extracting spec links: 2013 Alpina D3 Touring (F31)
# Extracting spec links: 2008 Alpina D3 Coupe (E92)
# Extracting spec links: 2005 Alpina D3 Touring (E91)
# Extracting spec links: 2005 Alpina D3 (E90)
# Extracting spec links: 2025 Alpina D4 Gran Coupe (G26, facelift 2024)
# Extracting spec links: 2022 Alpina D4 Gran Coupe (G26)
# Extracting spec links: 2017 Alpina D4 Coupe (F32, facelift 2017)
# Extracting spec links: 2017 Alpina D4 Cabrio (F33, facelift 2017)
# Extracting spec links: 2014 Alpina D4 Coupe (F32)
# Extracting spec links: 2014 Alpina D4 Cabrio (F33)
# Extracting spec links: 2020 Alpina D5 Sedan (G30, facelift 2020)
# Extracting spec links: 2020 Alpina D5 Touring (G31, facelift 2020)
# Extracting spec links: 2017 Alpina D5 Sedan (G30)
# Extracting spec links: 2017 Alpina D5 Touring (G31)
# Extracting spec links: 2013 Alpina D5 Sedan (F10 LCI, Facelift 2013)
# Extracting spec links: 2013 Alpina D5 Touring (F11 LCI, Facelift 2013)
# Extracting spec links: 2011 Alpina D5 Sedan (F10)
# Extracting spec links: 2011 Alpina D5 Touring (F11)
# Extracting spec links: 1990 Alpina RLE Roadster (Z1)
# Extracting spec links: 2003 Alpina Roadster S
# Extracting spec links: 2002 Alpina Roadster V8
# Extracting spec links: 2023 Alpina XB7 (facelift 2022)
# Extracting spec links: 2021 Alpina XB7
# Extracting spec links: 2022 Alpina XD3 (G01 LCI, facelift 2021)
# Extracting spec links: 2018 Alpina XD3 (G01)
# Extracting spec links: 2014 Alpina XD3 (F25 LCI, facelift 2014)
# Extracting spec links: 2013 Alpina XD3 (F25)
# Extracting spec links: 2022 Alpina XD4 (G02 LCI, facelift 2021)
# Extracting spec links: 2018 Alpina XD4 (G02)
# Extracting spec links: 1972 Aston Martin AMV8 Volante
# Extracting spec links: 1972 Aston Martin AMV8
# Extracting spec links: 1980 Aston Martin Bulldog
# Extracting spec links: 2018 Aston Martin Cygnet V8Extracting spec links: 2011 Aston Martin Cygnet
# Extracting spec links: 2019 Aston Martin DB11 Volante
#
# Extracting spec links: 2017 Aston Martin DB11
# Extracting spec links: 2024 Aston Martin DB12 Volante
# Extracting spec links: 2024 Aston Martin DB12
# Extracting spec links: 1961 Aston Martin DB4 Convertible
# Extracting spec links: 1961 Aston Martin DB4 (Series 3)
# Extracting spec links: 1960 Aston Martin DB4 GT Zagato
# Extracting spec links: 1959 Aston Martin DB4 GT
# Extracting spec links: 1958 Aston Martin DB4
# Extracting spec links: 1963 Aston Martin DB5
# Extracting spec links: 1969 Aston Martin DB6 Mark II
# Extracting spec links: 1966 Aston Martin DB6 Volante
# Extracting spec links: 1965 Aston Martin DB6
# Extracting spec links: 2003 Aston Martin DB7 AR1
# Extracting spec links: 2003 Aston Martin DB7 Zagato
# Extracting spec links: 2002 Aston Martin DB7 GT
# Extracting spec links: 1999 Aston Martin DB7 Vantage
# Extracting spec links: 1996 Aston Martin DB7 Volante
# Extracting spec links: 1994 Aston Martin DB7
# Extracting spec links: 2015 Aston Martin DB9 GT Volante
# Extracting spec links: 2015 Aston Martin DB9 GT Coupe
# Extracting spec links: 2012 Aston Martin DB9 Volante (facelift 2012)
# Extracting spec links: 2012 Aston Martin DB9 Coupe (facelift 2012)
# Extracting spec links: 2005 Aston Martin DB9 Coupe
# Extracting spec links: 2005 Aston Martin DB9 Volante
# Extracting spec links: 2019 Aston Martin DBS Superleggera Volante
# Extracting spec links: 2018 Aston Martin DBS Superleggera
# Extracting spec links: 2009 Aston Martin DBS V12 Volante
# Extracting spec links: 2008 Aston Martin DBS V12
# Extracting spec links: 1970 Aston Martin DBS V8
# Extracting spec links: 1967 Aston Martin DBS
# Extracting spec links: 2020 Aston Martin DBXExtracting spec links: 2022 Aston Martin Lagonda All-Terrain Concept
#
# Extracting spec links: 2021 Aston Martin Lagonda Vision Concept
# Extracting spec links: 1976 Aston Martin Lagonda I Shooting Brake
# Extracting spec links: 1976 Aston Martin Lagonda II
# Extracting spec links: 2009 Aston Martin One-77Extracting spec links: 2019 Aston Martin Rapide E
#
# Extracting spec links: 2018 Aston Martin Rapide AMR
# Extracting spec links: 2013 Aston Martin Rapide S
# Extracting spec links: 2010 Aston Martin Rapide
# Extracting spec links: 1983 Aston Martin Tickford Capri
# Extracting spec links: 2022 Aston Martin V12 Vantage Roadster
# Extracting spec links: 2022 Aston Martin V12 VantageExtracting spec links: 2016 Aston Martin V12 Vantage Roadster
#
# Extracting spec links: 2011 Aston Martin V12 Vantage
# Extracting spec links: 2025 Aston Martin V8 Vantage Roadster (2018), (facelift 2024)
# Extracting spec links: 2024 Aston Martin V8 Vantage (2018), (facelift 2024)
# Extracting spec links: 2020 Aston Martin V8 Vantage Roadster (2018)
# Extracting spec links: 2019 Aston Martin V8 Vantage (2018)
# Extracting spec links: 2008 Aston Martin V8 Vantage Roadster (facelift 2008)
# Extracting spec links: 2008 Aston Martin V8 Vantage (facelift 2008)
# Extracting spec links: 2005 Aston Martin V8 Vantage (2005)
# Extracting spec links: 2006 Aston Martin V8 Vantage Roadster (2005)
# Extracting spec links: 1993 Aston Martin V8 Vantage (II)
# Extracting spec links: 1977 Aston Martin V8 Volante
# Extracting spec links: 1977 Aston Martin V8 Vantage
# Extracting spec links: 2025 Aston Martin Valhalla
# Extracting spec links: 2021 Aston Martin Valhalla concept
# Extracting spec links: 2025 Aston Martin Valiant
# Extracting spec links: 2020 Aston Martin Valkyrie
# Extracting spec links: 2020 Aston Martin Valkyrie AM-RB 003
# Extracting spec links: 2018 Aston Martin Valkyrie AMR Pro
# Extracting spec links: 2024 Aston Martin Valour
# Extracting spec links: 2025 Aston Martin Vanquish III Volante
# Extracting spec links: 2025 Aston Martin Vanquish IIIExtracting spec links: 2022 Aston Martin Vanquish Vision Concept
#
# Extracting spec links: 2017 Aston Martin Vanquish S II Volante
# Extracting spec links: 2017 Aston Martin Vanquish S II
# Extracting spec links: 2014 Aston Martin Vanquish II Volante
# Extracting spec links: 2013 Aston Martin Vanquish II
# Extracting spec links: 2004 Aston Martin V12 Vanquish S
# Extracting spec links: 2001 Aston Martin V12 Vanquish
# Extracting spec links: 2011 Aston Martin Virage II Volante
# Extracting spec links: 2011 Aston Martin Virage II
# Extracting spec links: 1995 Aston Martin Virage Limited Edition
# Extracting spec links: 1994 Aston Martin Virage Saloon
# Extracting spec links: 1993 Aston Martin Virage Shooting Brake
# Extracting spec links: 1989 Aston Martin Virage Vantage
# Extracting spec links: 1990 Aston Martin Virage Volante
# Extracting spec links: 1990 Aston Martin Virage
# Extracting spec links: 2011 Aston Martin V12 Zagato
# Extracting spec links: 1987 Aston Martin Zagato Vantage
# Extracting spec links: 1987 Aston Martin Zagato Volante
# Extracting spec links: 1990 Audi 100 Avant (4A,C4)
# Extracting spec links: 1990 Audi 100 (4A,C4)
# Extracting spec links: 1988 Audi 100 Avant (C3, Typ 44, 44Q, facelift 1988)
# Extracting spec links: 1988 Audi 100 (C3, Typ 44,44Q, facelift 1988)
# Extracting spec links: 1982 Audi 100 Avant (C3, Typ 44, 44Q)
# Extracting spec links: 1982 Audi 100 (C3, Typ 44,44Q)
# Extracting spec links: 1979 Audi 100 Avant (C2, Typ 43, facelift 1979)
# Extracting spec links: 1979 Audi 100 (C2, Typ 43, facelift 1979)
# Extracting spec links: 1977 Audi 100 Avant (C2, Typ 43)
# Extracting spec links: 1976 Audi 100 (C2, Typ 43)
# Extracting spec links: 1974 Audi 100 (C1, facelift 1973)
# Extracting spec links: 1970 Audi 100 Coupe S
# Extracting spec links: 1968 Audi 100 (C1)
# Extracting spec links: 1984 Audi 200 Avant (C3, Typ 44,44Q)
# Extracting spec links: 1983 Audi 200 (C3, Typ 44,44Q)
# Extracting spec links: 1979 Audi 200 (C2, Typ 43)
# Extracting spec links: 1974 Audi 50 (Typ 86)
# Extracting spec links: 1976 Audi 5000 Sedan (C2)
# Extracting spec links: 1992 Audi 80 Avant (B4, Typ 8C)
# Extracting spec links: 1991 Audi 80 (B4, Typ 8C)
# Extracting spec links: 1986 Audi 80 (B3, Typ 89,89Q,8A)
# Extracting spec links: 1984 Audi 80 (B2, Typ 81,85, facelift 1984)
# Extracting spec links: 1978 Audi 80 (B2, Typ 81,85)
# Extracting spec links: 1976 Audi 80 (B1, Typ 82)
# Extracting spec links: 1975 Audi 80 Estate (B1, Typ 80)
# Extracting spec links: 1972 Audi 80 (B1, Typ 80)
# Extracting spec links: 1987 Audi 90 (B3, Typ 89,89Q,8A)Extracting spec links: 1984 Audi 90 (B2, Typ 81,85)
#
# Extracting spec links: 2022 Audi A1 allstreet (GB)
# Extracting spec links: 2019 Audi A1 Sportback (GB)
# Extracting spec links: 2019 Audi A1 citycarver (GB)
# Extracting spec links: 2014 Audi A1 (8X facelift 2014)
# Extracting spec links: 2014 Audi A1 Sportback (8X facelift 2014)
# Extracting spec links: 2011 Audi A1 Sportback (8X)
# Extracting spec links: 2010 Audi A1 (8X)
# Extracting spec links: 2000 Audi A2 (Typ 8Z)
# Extracting spec links: 2025 Audi A3 allstreet (8Y, facelift 2024)
# Extracting spec links: 2025 Audi A3 Sedan (8Y, facelift 2024)
# Extracting spec links: 2025 Audi A3 Sportback (8Y, facelift 2024)
# Extracting spec links: 2021 Audi A3 Sedan (8Y)
# Extracting spec links: 2021 Audi A3 Sportback (8Y)
# Extracting spec links: 2017 Audi A3 (8V, facelift 2016)
# Extracting spec links: 2017 Audi A3 Sedan (8V, facelift 2016)
# Extracting spec links: 2017 Audi A3 Sportback (8V, facelift 2016)
# Extracting spec links: 2017 Audi A3 Cabrio (8V, facelift 2016)
# Extracting spec links: 2013 Audi A3 (8V)
# Extracting spec links: 2014 Audi A3 Sedan (8V)
# Extracting spec links: 2013 Audi A3 Sportback (8V)
# Extracting spec links: 2014 Audi A3 Cabrio (8V)
# Extracting spec links: 2008 Audi A3 clubsport (8P, facelift 2008)
# Extracting spec links: 2008 Audi A3 (8P, facelift 2008)
# Extracting spec links: 2008 Audi A3 Cabrio (8P, facelift 2008)
# Extracting spec links: 2008 Audi A3 Sportback (8PA, facelift 2008)
# Extracting spec links: 2006 Audi A3 (8P, facelift 2005)
# Extracting spec links: 2005 Audi A3 Sportback (8PA)
# Extracting spec links: 2004 Audi A3 (8P)
# Extracting spec links: 2001 Audi A3 (8L, facelift 2000)
# Extracting spec links: 1997 Audi A3 (8L)
# Extracting spec links: 2020 Audi A4 (B9 8W, facelift 2019)
# Extracting spec links: 2020 Audi A4 Avant (B9 8W, facelift 2019)
# Extracting spec links: 2020 Audi A4 allroad (B9 8W, facelift 2019)
# Extracting spec links: 2019 Audi A4 (B9 8W, facelift 2018)
# Extracting spec links: 2019 Audi A4 Avant (B9 8W, facelift 2018)
# Extracting spec links: 2017 Audi A4 allroad (B9 8W)
# Extracting spec links: 2016 Audi A4 (B9 8W)
# Extracting spec links: 2016 Audi A4 Avant (B9 8W)
# Extracting spec links: 2011 Audi A4 allroad (B8 8K, facelift 2011)
# Extracting spec links: 2011 Audi A4 (B8 8K, facelift 2011)
# Extracting spec links: 2011 Audi A4 Avant (B8 8K, facelift 2011)
# Extracting spec links: 2010 Audi A4 allroad (B8 8K)
# Extracting spec links: 2009 Audi A4 Avant (B8 8K)
# Extracting spec links: 2008 Audi A4 (B8 8K)
# Extracting spec links: 2006 Audi A4 Cabriolet (B7 8H)
# Extracting spec links: 2005 Audi A4 (B7 8E)
# Extracting spec links: 2005 Audi A4 Avant (B7 8E)
# Extracting spec links: 2002 Audi A4 Cabriolet (B6 8H)
# Extracting spec links: 2002 Audi A4 Avant (B6 8E)
# Extracting spec links: 2001 Audi A4 (B6 8E)
# Extracting spec links: 1999 Audi A4 Avant (B5, Typ 8D, facelift 1999)
# Extracting spec links: 1999 Audi A4 (B5, Typ 8D, facelift 1999)
# Extracting spec links: 1996 Audi A4 Avant (B5, Typ 8D)
# Extracting spec links: 1995 Audi A4 (B5, Typ 8D)
# Extracting spec links: 2025 Audi A5 Long Sportback (B10)
# Extracting spec links: 2025 Audi A5 Long (B10)
# Extracting spec links: 2025 Audi A5 Avant (B10)
# Extracting spec links: 2025 Audi A5 Sedan (B10)
# Extracting spec links: 2020 Audi A5 Sportback (F5, facelift 2019)
# Extracting spec links: 2020 Audi A5 Coupe (F5, facelift 2019)
# Extracting spec links: 2020 Audi A5 Cabriolet (F5, facelift 2019)
# Extracting spec links: 2017 Audi A5 Sportback (F5)
# Extracting spec links: 2017 Audi A5 Coupe (F5)
# Extracting spec links: 2017 Audi A5 Cabriolet (F5)Extracting spec links: 2012 Audi A5 Sportback (8TA, facelift 2011)
#
# Extracting spec links: 2012 Audi A5 Coupe (8T3, facelift 2011)
# Extracting spec links: 2012 Audi A5 Cabriolet (8F7, facelift 2011)
# Extracting spec links: 2010 Audi A5 Sportback (8TA)
# Extracting spec links: 2009 Audi A5 Cabriolet (8F7)
# Extracting spec links: 2008 Audi A5 Coupe (8T3)
# Extracting spec links: 2026 Audi A6 Sedan (C9)
# Extracting spec links: 2026 Audi A6 Avant (C9)
# Extracting spec links: 2024 Audi A6 Avant (C8, facelift 2023)
# Extracting spec links: 2024 Audi A6 Sedan (C8, facelift 2023)
# Extracting spec links: 2019 Audi A6 Long (C8)
# Extracting spec links: 2019 Audi A6 Allroad quattro (C8)
# Extracting spec links: 2019 Audi A6 Sedan (C8)
# Extracting spec links: 2019 Audi A6 Avant (C8)
# Extracting spec links: 2017 Audi A6 Allroad quattro (4G, C7 facelift 2016)
# Extracting spec links: 2017 Audi A6 Sedan (4G, C7 facelift 2016)
# Extracting spec links: 2017 Audi A6 Avant (4G, C7 facelift 2016)
# Extracting spec links: 2015 Audi A6 Allroad quattro (4G, C7 facelift 2014)
# Extracting spec links: 2015 Audi A6 Sedan (4G, C7 facelift 2014)
# Extracting spec links: 2015 Audi A6 Avant (4G, C7 facelift 2014)
# Extracting spec links: 2013 Audi A6 Allroad quattro (4G, C7)
# Extracting spec links: 2011 Audi A6 Sedan (4G, C7)
# Extracting spec links: 2011 Audi A6 Avant (4G, C7)
# Extracting spec links: 2009 Audi A6 Allroad quattro (4F,C6 facelift 2008)
# Extracting spec links: 2009 Audi A6 (4F,C6 facelift 2008)
# Extracting spec links: 2009 Audi A6 Avant (4F,C6 facelift 2008)
# Extracting spec links: 2007 Audi A6 Allroad quattro (4F,C6)
# Extracting spec links: 2005 Audi A6 (4F,C6)
# Extracting spec links: 2005 Audi A6 Avant (4F,C6)
# Extracting spec links: 2002 Audi A6 (4B,C5, facelift 2001)Extracting spec links: 2002 Audi A6 Avant (4B,C5, facelift 2001)
#
# Extracting spec links: 2001 Audi A6 Allroad quattro (4B,C5)
# Extracting spec links: 1998 Audi A6 (4B,C5)
# Extracting spec links: 1998 Audi A6 Avant (4B,C5)
# Extracting spec links: 1995 Audi A6 (4A,C4)
# Extracting spec links: 1995 Audi A6 Avant (4A,C4)
# Extracting spec links: 2025 Audi A6 Avant e-tron
# Extracting spec links: 2025 Audi A6 Sportback e-tron
# Extracting spec links: 2021 Audi A6 e-tron concept
# Extracting spec links: 2024 Audi A7 Sportback (C8, facelift 2023)
# Extracting spec links: 2021 Audi A7L Sedan
# Extracting spec links: 2018 Audi A7 Sportback (C8)
# Extracting spec links: 2015 Audi A7 Sportback (C7, facelift 2014)
# Extracting spec links: 2011 Audi A7 Sportback (C7)
# Extracting spec links: 2022 Audi A8 Long Horch (D5, facelift 2021)
# Extracting spec links: 2022 Audi A8 (D5, facelift 2021)
# Extracting spec links: 2022 Audi A8 Long (D5, facelift 2021)
# Extracting spec links: 2018 Audi A8 (D5)
# Extracting spec links: 2018 Audi A8 Long (D5)
# Extracting spec links: 2014 Audi A8 (D4,4H facelift 2013)
# Extracting spec links: 2014 Audi A8 Long (D4,4H facelift 2013)
# Extracting spec links: 2011 Audi A8 (D4, 4H)
# Extracting spec links: 2011 Audi A8 Long (D4, 4H)
# Extracting spec links: 2007 Audi A8 (D3, 4E, facelift 2007)
# Extracting spec links: 2007 Audi A8 Long (D3, 4E, facelift 2007)
# Extracting spec links: 2005 Audi A8 (D3, 4E, facelift 2005)
# Extracting spec links: 2005 Audi A8 Long (D3, 4E, facelift 2005)
# Extracting spec links: 2004 Audi A8 (D3, 4E)
# Extracting spec links: 2003 Audi A8 Long (D3, 4E)
# Extracting spec links: 2000 Audi A8 Long (D2, 4D, facelift 1999)
# Extracting spec links: 1999 Audi A8 (D2, 4D, facelift 1998)
# Extracting spec links: 1995 Audi A8 (D2, 4D)
# Extracting spec links: 2017 Audi Aicon Concept
# Extracting spec links: 1997 Audi Cabriolet (B3 8G, facelift 1997)
# Extracting spec links: 1992 Audi Cabriolet (B3 8G)
# Extracting spec links: 1991 Audi Coupe (B4 8C)
# Extracting spec links: 1989 Audi Coupe (B3 89)
# Extracting spec links: 1985 Audi Coupe (B2 81, 85, facelift 1984)
# Extracting spec links: 1981 Audi Coupe (B2 81, 85)
# Extracting spec links: 2020 Audi e-tron Sportback
# Extracting spec links: 2019 Audi e-tron
# Extracting spec links: 2025 Audi e-tron GT (facelift 2025)
# Extracting spec links: 2021 Audi e-tron GT
# Extracting spec links: 2019 Audi e-tron GT Concept
# Extracting spec links: 1973 Audi Fox (B1)
# Extracting spec links: 2013 Audi nanuk quattro concept
# Extracting spec links: 1968 Audi NSU RO 80
# Extracting spec links: 2019 Audi PB18 concept
# Extracting spec links: 2021 Audi Q2 (facelift 2020)
# Extracting spec links: 2017 Audi Q2
# Extracting spec links: 2019 Audi Q3 Sportback (F3)
# Extracting spec links: 2019 Audi Q3 (F3)
# Extracting spec links: 2015 Audi Q3 (8U facelift 2014)
# Extracting spec links: 2012 Audi Q3 (8U)
# Extracting spec links: 2022 Audi Q4 Sportback e-tron
# Extracting spec links: 2021 Audi Q4 e-tron
# Extracting spec links: 2020 Audi Q4 Sportback e-tron concept
# Extracting spec links: 2020 Audi Q4 e-tron Concept
# Extracting spec links: 2025 Audi Q5 III Sportback
# Extracting spec links: 2025 Audi Q5 III
# Extracting spec links: 2021 Audi Q5 II Sportback (FY, facelift 2020)
# Extracting spec links: 2021 Audi Q5 II (FY, facelift 2020)
# Extracting spec links: 2018 Audi Q5L II (FY)
# Extracting spec links: 2018 Audi Q5 II (FY)
# Extracting spec links: 2013 Audi Q5 I (8R, facelift 2012)
# Extracting spec links: 2009 Audi Q5 I (8R)
# Extracting spec links: 2025 Audi Q6 Sportback e-tron
# Extracting spec links: 2024 Audi Q6 e-tron
# Extracting spec links: 2025 Audi Q7 (Typ 4M, facelift 2024)
# Extracting spec links: 2020 Audi Q7 (Typ 4M, facelift 2019)
# Extracting spec links: 2016 Audi Q7 (Typ 4M)
# Extracting spec links: 2010 Audi Q7  (Typ 4L, facelift 2009)
# Extracting spec links: 2006 Audi Q7 (Typ 4L)
# Extracting spec links: 2023 Audi Q8 (4M, facelift 2023)
# Extracting spec links: 2019 Audi Q8 (4M)
# Extracting spec links: 2023 Audi Q8 e-tron Sportback
# Extracting spec links: 2023 Audi Q8 e-tron
# Extracting spec links: 1980 Audi Quattro (Typ 85)
# Extracting spec links: 2019 Audi R8 II Coupe (4S, facelift 2019)
# Extracting spec links: 2019 Audi R8 II Spyder (4S, facelift 2019)
# Extracting spec links: 2019 Audi R8 II LMS (facelift 2019)
# Extracting spec links: 2016 Audi R8 II Spyder (4S)
# Extracting spec links: 2016 Audi R8 II LMS
# Extracting spec links: 2015 Audi R8 II Coupe (4S)
# Extracting spec links: 2013 Audi R8 LMS ultra
# Extracting spec links: 2012 Audi R8 Spyder (42, facelift 2012)
# Extracting spec links: 2012 Audi R8 Coupe (42, facelift 2012)
# Extracting spec links: 2010 Audi R8 Spyder (42)Extracting spec links: 2006 Audi R8 Coupe (42)
#
# Extracting spec links: 1994 Audi RS 2 Avant
# Extracting spec links: 2025 Audi RS 3 Sportback (8Y, facelift 2024)
# Extracting spec links: 2025 Audi RS 3 Sedan (8Y, facelift 2024)
# Extracting spec links: 2022 Audi RS 3 Sportback (8Y)
# Extracting spec links: 2022 Audi RS 3 Sedan (8Y)
# Extracting spec links: 2017 Audi RS 3 sportback (8VA, facelift 2017)
# Extracting spec links: 2017 Audi RS 3 sedan (8V, facelift 2017)
# Extracting spec links: 2015 Audi RS 3 sportback (8VA)
# Extracting spec links: 2012 Audi RS 3 sportback (8PA)
# Extracting spec links: 2020 Audi RS 4 Avant (B9, facelift 2019)
# Extracting spec links: 2018 Audi RS 4 Avant (B9)
# Extracting spec links: 2012 Audi RS 4 Avant (B8) (facelift 2011)
# Extracting spec links: 2006 Audi RS 4 Cabrio (8E, B7)
# Extracting spec links: 2006 Audi RS 4 Avant (8E, B7)
# Extracting spec links: 2006 Audi RS 4 Salon (8E, B7)
# Extracting spec links: 2000 Audi RS 4 Avant (8D, B5)
# Extracting spec links: 2020 Audi RS 5 Sportback (F5, facelift 2020)
# Extracting spec links: 2020 Audi RS 5 Coupe II (F5, facelift 2020)
# Extracting spec links: 2019 Audi RS 5 Sportback (F5)
# Extracting spec links: 2018 Audi RS 5 Coupe II (F5)
# Extracting spec links: 2013 Audi RS 5 Cabriolet (8T, facelift 2013)Extracting spec links: 2012 Audi RS 5 Coupe (8T, facelift 2012)
# Extracting spec links: 2010 Audi RS 5 Coupe (8T)
#
# Extracting spec links: 2020 Audi RS 6 Avant (C8)
# Extracting spec links: 2015 Audi RS 6 Avant (C7, facelift 2014)
# Extracting spec links: 2013 Audi RS 6 Avant (C7)
# Extracting spec links: 2008 Audi RS 6 (4F,C6)
# Extracting spec links: 2008 Audi RS 6 Avant (4F,C6)
# Extracting spec links: 2002 Audi RS 6 (4B,C5)
# Extracting spec links: 2002 Audi RS 6 Avant  (4B,C5)
# Extracting spec links: 2020 Audi RS 7 Sportback (C8)
# Extracting spec links: 2013 Audi RS 7 Sportback (C7)
# Extracting spec links: 2025 Audi RS e-tron GT (facelift 2024)
# Extracting spec links: 2021 Audi RS e-tron GT
# Extracting spec links: 2019 Audi RS Q3 (F3)
# Extracting spec links: 2020 Audi RS Q3 Sportback
# Extracting spec links: 2016 Audi RS Q3 (facelift 2015)
# Extracting spec links: 2013 Audi RS Q3
# Extracting spec links: 2025 Audi RS Q8 (4M, facelift 2024)Extracting spec links: 2020 Audi RS Q8 (4M)
#
# Extracting spec links: 2025 Audi S e-tron GT
# Extracting spec links: 2015 Audi S1 Sportback
# Extracting spec links: 2015 Audi S1
# Extracting spec links: 1993 Audi S2
# Extracting spec links: 1992 Audi S2 Avant
# Extracting spec links: 1991 Audi S2 Coupe
# Extracting spec links: 2024 Audi S3 Sportback (8Y, facelift 2024)
# Extracting spec links: 2024 Audi S3 Sedan (8Y, facelift 2024)
# Extracting spec links: 2021 Audi S3 Sportback (8Y)
# Extracting spec links: 2021 Audi S3 Sedan (8Y)
# Extracting spec links: 2016 Audi S3 Sportback (8V, facelift 2016)
# Extracting spec links: 2016 Audi S3 (8V, facelift 2016)
# Extracting spec links: 2016 Audi S3 Sedan (8V, facelift 2016)
# Extracting spec links: 2016 Audi S3 Cabriolet (8V, facelift 2016)
# Extracting spec links: 2014 Audi S3 Cabriolet (8V)
# Extracting spec links: 2013 Audi S3 Sportback (8V)
# Extracting spec links: 2013 Audi S3 (8V)
# Extracting spec links: 2013 Audi S3 Sedan (8V)
# Extracting spec links: 2008 Audi S3 Sportback (8PA)
# Extracting spec links: 2008 Audi S3 (8P, facelift 2008)
# Extracting spec links: 2007 Audi S3 (8P)
# Extracting spec links: 2001 Audi S3 (8L, facelift 2001)
# Extracting spec links: 1999 Audi S3 (8L)
# Extracting spec links: 2019 Audi S4 (B9, facelift 2019)
# Extracting spec links: 2019 Audi S4 Avant (B9, facelift 2019)
# Extracting spec links: 2016 Audi S4 (B9)
# Extracting spec links: 2016 Audi S4 Avant (B9)
# Extracting spec links: 2011 Audi S4 (B8, facelift 2011)
# Extracting spec links: 2011 Audi S4 Avant (B8, facelift 2011)
# Extracting spec links: 2009 Audi S4 (B8)
# Extracting spec links: 2009 Audi S4 Avant (B8)
# Extracting spec links: 2005 Audi S4 Cabriolet (8E,B7)
# Extracting spec links: 2005 Audi S4 (8E,B7)
# Extracting spec links: 2005 Audi S4 Avant (8E,B7)
# Extracting spec links: 2003 Audi S4 Cabriolet (8E,B6)
# Extracting spec links: 2003 Audi S4 (8E,B6)
# Extracting spec links: 2003 Audi S4 Avant (8E,B6)
# Extracting spec links: 1998 Audi S4 (8D,B5)
# Extracting spec links: 1998 Audi S4 Avant (8D,B5)
# Extracting spec links: 1992 Audi S4 (4A,C4)
# Extracting spec links: 1992 Audi S4 Avant (4A,C4)
# Extracting spec links: 2025 Audi S5 Avant (B10)
# Extracting spec links: 2025 Audi S5 Sedan (B10)
# Extracting spec links: 2020 Audi S5 Cabriolet (F5, facelift 2019)
# Extracting spec links: 2020 Audi S5 Sportback (F5, facelift 2019)
# Extracting spec links: 2020 Audi S5 Coupe (F5, facelift 2019)
# Extracting spec links: 2017 Audi S5 Sportback (F5)
# Extracting spec links: 2017 Audi S5 Cabriolet (F5)
# Extracting spec links: 2017 Audi S5 Coupe (F5)
# Extracting spec links: 2012 Audi S5 Sportback (8T, facelift 2011)
# Extracting spec links: 2012 Audi S5 Cabriolet (8T, facelift 2011)
# Extracting spec links: 2012 Audi S5 Coupe (8T, facelift 2011)
# Extracting spec links: 2010 Audi S5 Sportback (8T)
# Extracting spec links: 2010 Audi S5 Cabriolet (8T)
# Extracting spec links: 2007 Audi S5 Coupe (8T)
# Extracting spec links: 2024 Audi S6 Avant (C8, facelift 2023)
# Extracting spec links: 2024 Audi S6 (C8, facelift 2023)
# Extracting spec links: 2020 Audi S6 Avant (C8)
# Extracting spec links: 2020 Audi S6 (C8)
# Extracting spec links: 2016 Audi S6 (C7 facelift 2016)
# Extracting spec links: 2016 Audi S6 Avant (C7 facelift 2016)
# Extracting spec links: 2014 Audi S6 (C7 facelift 2014)
# Extracting spec links: 2014 Audi S6 Avant (C7 facelift 2014)
# Extracting spec links: 2013 Audi S6 (C7)
# Extracting spec links: 2013 Audi S6 Avant (C7)
# Extracting spec links: 2008 Audi S6 (4F,C6 facelift 2008)
# Extracting spec links: 2008 Audi S6 Avant (4F,C6 facelift 2008)
# Extracting spec links: 2006 Audi S6 (4F,C6)
# Extracting spec links: 2006 Audi S6 Avant (4F,C6)
# Extracting spec links: 2000 Audi S6 (4B,C5)
# Extracting spec links: 2000 Audi S6 Avant  (4B,C5)
# Extracting spec links: 1995 Audi S6 (4A,C4)
# Extracting spec links: 1995 Audi S6 Avant (4A,C4)
# Extracting spec links: 2025 Audi S6 Avant e-tron
# Extracting spec links: 2025 Audi S6 Sportback e-tron
# Extracting spec links: 2024 Audi S7 Sportback (C8, facelift 2023)
# Extracting spec links: 2020 Audi S7 Sportback (C8)
# Extracting spec links: 2016 Audi S7 Sportback (C7 facelift 2016)
# Extracting spec links: 2014 Audi S7 Sportback (C7 facelift 2014)
# Extracting spec links: 2012 Audi S7 Sportback (C7)
# Extracting spec links: 2022 Audi S8 (D5, facelift 2021)
# Extracting spec links: 2020 Audi S8 (D5)
# Extracting spec links: 2013 Audi S8 (D4 facelift 2013)
# Extracting spec links: 2012 Audi S8 (D4)
# Extracting spec links: 2007 Audi S8 (D3, facelift 2007)
# Extracting spec links: 2006 Audi S8 (D3)
# Extracting spec links: 1996 Audi S8 (D2)
# Extracting spec links: 2021 Audi Skysphere (Concept)
# Extracting spec links: 2021 Audi SQ2 (facelift 2020)
# Extracting spec links: 2019 Audi SQ2
# Extracting spec links: 2025 Audi SQ5 III Sportback
# Extracting spec links: 2025 Audi SQ5 III
# Extracting spec links: 2021 Audi SQ5 II Sportback (FY, facelift 2020)
# Extracting spec links: 2021 Audi SQ5 II (FY, facelift 2020)
# Extracting spec links: 2018 Audi SQ5 II (FY)
# Extracting spec links: 2014 Audi SQ5 I (8R)
# Extracting spec links: 2025 Audi SQ6 Sportback e-tron
# Extracting spec links: 2024 Audi SQ6 e-tron
# Extracting spec links: 2025 Audi SQ7 (Typ 4M, facelift 2024)
# Extracting spec links: 2020 Audi SQ7 (Typ 4M, facelift 2019)
# Extracting spec links: 2017 Audi SQ7 (Typ 4M)
# Extracting spec links: 2023 Audi SQ8 (4M, facelift 2023)
# Extracting spec links: 2020 Audi SQ8 (4M)
# Extracting spec links: 2023 Audi SQ8 e-tron Sportback
# Extracting spec links: 2023 Audi SQ8 e-tron
# Extracting spec links: 2019 Audi TT RS Roadster (8S, facelift 2019)
# Extracting spec links: 2019 Audi TT RS Coupe (8S, facelift 2019)
# Extracting spec links: 2019 Audi TTS Roadster (8S, facelift 2018)
# Extracting spec links: 2019 Audi TTS Coupe (8S, facelift 2018)
# Extracting spec links: 2019 Audi TT Roadster (8S, facelift 2018)
# Extracting spec links: 2019 Audi TT Coupe (8S, facelift 2018)
# Extracting spec links: 2017 Audi TT RS Roadster (8S)
# Extracting spec links: 2017 Audi TT RS Coupe (8S)
# Extracting spec links: 2015 Audi TTS Roadster (8S)
# Extracting spec links: 2015 Audi TTS Coupe (8S)
# Extracting spec links: 2015 Audi TT Roadster (8S)
# Extracting spec links: 2015 Audi TT Coupe (8S)
# Extracting spec links: 2010 Audi TT RS Roadster (8J, facelift 2010)
# Extracting spec links: 2010 Audi TT RS Coupe (8J, facelift 2010)
# Extracting spec links: 2010 Audi TTS Roadster (8J, facelift 2010)
# Extracting spec links: 2010 Audi TTS Coupe (8J, facelift 2010)
# Extracting spec links: 2010 Audi TT Roadster (8J, facelift 2010)
# Extracting spec links: 2010 Audi TT Coupe (8J, facelift 2010)
# Extracting spec links: 2010 Audi TT RS Roadster (8J)
# Extracting spec links: 2010 Audi TT RS Coupe (8J)
# Extracting spec links: 2009 Audi TTS Roadster (8J)
# Extracting spec links: 2007 Audi TTS Coupe (8J)
# Extracting spec links: 2007 Audi TT Roadster (8J)
# Extracting spec links: 2007 Audi TT Coupe (8J)
# Extracting spec links: 2001 Audi TT Roadster (8N, facelift 2000)
# Extracting spec links: 2001 Audi TT Coupe (8N, facelift 2000)
# Extracting spec links: 2000 Audi TT Roadster (8N)
# Extracting spec links: 1999 Audi TT Coupe (8N)
# Extracting spec links: 1991 Audi V8 Long (D11)
# Extracting spec links: 1989 Audi V8 (D11)
# Extracting spec links: 2002 Bentley Arnage R
# Extracting spec links: 2002 Bentley Arnage T
# Extracting spec links: 1998 Bentley Arnage I
# Extracting spec links: 2006 Bentley Azure II
# Extracting spec links: 1995 Bentley Azure
# Extracting spec links: 2021 Bentley Mulliner Bacalar
# Extracting spec links: 2024 Bentley Batur Convertible
# Extracting spec links: 2023 Bentley Batur
# Extracting spec links: 2023 Bentley Bentayga EWB
# Extracting spec links: 2021 Bentley Bentayga (facelift 2020)
# Extracting spec links: 2016 Bentley Bentayga
# Extracting spec links: 2008 Bentley Brooklands II
# Extracting spec links: 1993 Bentley Brooklands
# Extracting spec links: 2025 Bentley Continental GTC IV
# Extracting spec links: 2025 Bentley Continental GT IV
# Extracting spec links: 2019 Bentley Continental GTC III
# Extracting spec links: 2018 Bentley Continental GT III
# Extracting spec links: 2015 Bentley Continental GTC II (facelift 2015)
# Extracting spec links: 2015 Bentley Continental GT II (facelift 2015)
# Extracting spec links: 2011 Bentley Continental GTC II
# Extracting spec links: 2011 Bentley Continental GT IIExtracting spec links: 2006 Bentley Continental GTC
#
# Extracting spec links: 2005 Bentley Continental Flying Spur
# Extracting spec links: 2003 Bentley Continental GT
# Extracting spec links: 1996 Bentley Continental T
# Extracting spec links: 1991 Bentley Continental R
# Extracting spec links: 1984 Bentley Continental
# Extracting spec links: 2025 Bentley Flying Spur IV
# Extracting spec links: 2019 Bentley Flying Spur III
# Extracting spec links: 2015 Bentley Flying Spur II (facelift 2015)
# Extracting spec links: 2013 Bentley Flying Spur II
# Extracting spec links: 1946 Bentley Mark VI
# Extracting spec links: 2016 Bentley Mulsanne EWB
# Extracting spec links: 2016 Bentley Mulsanne II (Facelift 2016)
# Extracting spec links: 2010 Bentley Mulsanne II
# Extracting spec links: 1980 Bentley Mulsanne I
# Extracting spec links: 1985 Bentley Turbo R
# Extracting spec links: 1966 BMW 02 (E10)
# Extracting spec links: 2025 BMW 1 Series Hatchback (F70)
# Extracting spec links: 2019 BMW 1 Series Hatchback (F40)
# Extracting spec links: 2017 BMW 1 Series Sedan (F52)
# Extracting spec links: 2017 BMW 1 Series Hatchback 5dr (F20 LCI, facelift 2017)
# Extracting spec links: 2017 BMW 1 Series Hatchback 3dr (F21 LCI, facelift 2017)
# Extracting spec links: 2015 BMW 1 Series Hatchback 5dr (F20 LCI, facelift 2015)
# Extracting spec links: 2015 BMW 1 Series Hatchback 3dr (F21 LCI, facelift 2015)
# Extracting spec links: 2012 BMW 1 Series Hatchback 3dr (F21)
# Extracting spec links: 2011 BMW 1 Series Hatchback 5dr (F20)
# Extracting spec links: 2011 BMW 1 Series Convertible (E88 LCI, facelift 2011)
# Extracting spec links: 2001 BMW 3 Series Convertible (E46, facelift 2001)
# Extracting spec links: 2000 BMW 3 Series Convertible (E46)
# Extracting spec links: 1999 BMW 3 Series Touring (E46)
# Extracting spec links: 1999 BMW 3 Series Coupe (E46)
# Extracting spec links: 1998 BMW 3 Series Sedan (E46)
# Extracting spec links: 1994 BMW 3 Series Touring (E36)
# Extracting spec links: 1993 BMW 3 Series Compact (E36)
# Extracting spec links: 1993 BMW 3 Series Convertible (E36)
# Extracting spec links: 1992 BMW 3 Series Coupe (E36)
# Extracting spec links: 1991 BMW 3 Series Sedan (E36)
# Extracting spec links: 1988 BMW 3 Series Touring (E30, facelift 1987)
# Extracting spec links: 1987 BMW 3 Series Convertible (E30, facelift 1987)
# Extracting spec links: 1987 BMW 3 Series Sedan (E30, facelift 1987)
# Extracting spec links: 1987 BMW 3 Series Coupe (E30, facelift 1987)
# Extracting spec links: 1985 BMW 3 Series Convertible (E30)
# Extracting spec links: 1982 BMW 3 Series Sedan (E30)
# Extracting spec links: 1982 BMW 3 Series Coupe (E30)
# Extracting spec links: 1975 BMW 3 Series (E21)
# Extracting spec links: 2023 BMW 3.0 CSL
# Extracting spec links: 2025 BMW 4 Series Gran Coupe (G26 LCI, facelift 2024)
# Extracting spec links: 2025 BMW 4 Series Convertible (G23 LCI, facelift 2024)
# Extracting spec links: 2025 BMW 4 Series Coupe (G22 LCI, facelift 2024)
# Extracting spec links: 2021 BMW 4 Series Gran Coupe (G26)
# Extracting spec links: 2021 BMW 4 Series Convertible (G23)
# Extracting spec links: 2021 BMW 4 Series Coupe (G22)
# Extracting spec links: 2019 BMW 4 Series Concept 4
# Extracting spec links: 2017 BMW 4 Series Gran Coupe (F36, facelift 2017)Extracting spec links: 2017 BMW 4 Series Convertible (F33, facelift 2017)
#
# Extracting spec links: 2017 BMW 4 Series Coupe (F32, facelift 2017)
# Extracting spec links: 2014 BMW 4 Series Gran Coupe (F36)
# Extracting spec links: 2014 BMW 4 Series Convertible (F33)
# Extracting spec links: 2013 BMW 4 Series Coupe (F32)
# Extracting spec links: 2024 BMW 5 Series Touring (G61)
# Extracting spec links: 2024 BMW 5 Series Sedan (G60)
# Extracting spec links: 2021 BMW 5 Series Sedan (G30 LCI, facelift 2020)
# Extracting spec links: 2021 BMW 5 Series Touring (G31 LCI, facelift 2020)
# Extracting spec links: 2017 BMW 5 Series Sedan (G30)Extracting spec links: 2017 BMW 5 Series Touring (G31)
#
# Extracting spec links: 2013 BMW 5 Series Active Hybrid (F10H LCI, facelift 2013)
# Extracting spec links: 2013 BMW 5 Series Gran Turismo (F07 LCI, Facelift 2013)
# Extracting spec links: 2013 BMW 5 Series Sedan (F10 LCI, Facelift 2013)
# Extracting spec links: 2013 BMW 5 Series Touring (F11 LCI, Facelift 2013)
# Extracting spec links: 2011 BMW 5 Series Active Hybrid (F10)
# Extracting spec links: 2010 BMW 5 Series Sedan (F10)
# Extracting spec links: 2009 BMW 5 Series Gran Turismo (F07)
